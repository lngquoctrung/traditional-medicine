# %% [markdown]
# ## **0. Dataset Overview**
#
# Data extracted from Vietnamese Traditional Medicine documents include:
#
# 1. **Medicinal herbs**: Detailed information about Oriental medicine
#
# 2. **Prescriptions**: Traditional medicine
#
# 3. **Formulas**: Dosage and combination of medicinal herbs
#
# ## **Processing Pipeline**
#
# 1. PDF Chunking: Split 1300 pages into chunks of 200 pages/chunk with 30 pages overlap
# 2. Gemini API: Upload chunks and extract in groups of 8 pages with 3 pages overlap
# 3. Deduplication: Fuzzy matching with similarity threshold 0.85
# 4. Export: JSON + CSV format

# %% [markdown]
# ## **1. Import libraries**

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Setup plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)

# Add project root to path
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

# %%
from src.settings import settings
from src.dataset import DataExtractor

# %% [markdown]
# ## **2. Run extraction**

# %%
extractor = DataExtractor(
    settings=settings,
    logger_name="HerbExtractor",
    logger_path=f"{settings.LOG_PATH}/extraction.log"
)

pdf_file = f"{settings.RAW_DATA_PATH}/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf"

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Processing: {pdf_file}\n")

try:
    results = extractor.process_pdf_file(str(pdf_file))
    
    end_time = datetime.now()
    duration = (end_time - start_time).total_seconds()
    
    print(f"Extraction completed successfully!")
    print(f"Duration: {duration/60:.1f} minutes ({duration:.0f} seconds)")
    print(f"Results saved to: {settings.PROCESSED_DATA_PATH}")
    
except Exception as e:
    print(f"Error during extraction: {e}")
    raise
# Out:
# Started at: 2025-11-21 14:36:14
# Processing: /home/qctrung/Projects/machine-learning/traditional_medicine/data/raw/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf
#
# 2025-11-21 14:36:14 - HerbExtractor - INFO - Processing: data/raw/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf
# 2025-11-21 14:36:14 - HerbExtractor - INFO - Model: gemini-2.0-flash
# 2025-11-21 14:36:14 - HerbExtractor - INFO - Rate limit: 15 RPM
# 2025-11-21 14:36:16 - HerbExtractor - INFO - Created: chunk_000_pages_0001-0200.pdf (200 pages)
# 2025-11-21 14:36:16 - HerbExtractor - INFO - Created: chunk_001_pages_0171-0370.pdf (200 pages)
# 2025-11-21 14:36:17 - HerbExtractor - INFO - Created: chunk_002_pages_0341-0540.pdf (200 pages)
# 2025-11-21 14:36:17 - HerbExtractor - INFO - Created: chunk_003_pages_0511-0710.pdf (200 pages)
# 2025-11-21 14:36:18 - HerbExtractor - INFO - Created: chunk_004_pages_0681-0880.pdf (200 pages)
# 2025-11-21 14:36:18 - HerbExtractor - INFO - Created: chunk_005_pages_0851-1050.pdf (200 pages)
# 2025-11-21 14:36:19 - HerbExtractor - INFO - Created: chunk_006_pages_1021-1220.pdf (200 pages)
# 2025-11-21 14:36:19 - HerbExtractor - INFO - Created: chunk_007_pages_1191-1294.pdf (104 pages)

#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa bệnh phụ nữ, nhất là đối với phụ nữ sau khi sinh nở, đẻ xong bị rong huyết (cầm máu tử cung), chữa viêm niêm mạc dạ con, kinh nguyệt quá nhiều. Còn dùng chữa huyết áp cao, thuốc bổ huyết, các bệnh về tuần hoàn cơ tim, thần kinh của tim, chứng tìm hẹp nhẹ (stenocardie), chữa lỵ. Quả ích mẫu dùng với tên sung úy tứ làm thuốc thông tiểu, chữa phù thũng, thiên đầu thống (glôcôm). Dùng ngoài thân và quả ích mẫu giã đắp hay sắc lấy nước rửa chữa một số bệnh như sưng vú, chốc đầu, lở ngứa.",
#       "lieu_dung": "6-12g",
#       "ghi_chu": "Những người có đồng tử mở rộng không dùng được"
#     },
#     {
#       "ten_viet_nam": "HƯƠNG PHỤ",
#       "ten_goi_khac": "củ gấu, cỏ gấu, cỏ cú",
#       "ten_khoa_hoc": "Cyperus rotundus L.",
#       "ho_thuc_vat": "Cói Cyperaccae",
#       "mo_ta": "Cỏ gấu là một loại cỏ sống lâu năm, cao 20-60cm, thân rễ phát triển thành củ, tùy theo đất rắn hay xốp củ phát triển to hay nhỏ, ở vùng bờ biển củ to dài còn gọi là hải hương phụ (hương phụ vùng biển). Lá nhỏ hẹp, ở giữa lưng có gân nổi lên, cứng và bóng, phần dưới lá ôm lấy thân cây.\nVào tháng 6, trên ngọn cây có 3 đến 8 cụm hoa hình tán màu xám nâu, hoa lưỡng tính, 3 nhị dài chừng 2mm, nhụy có đầu núm chia thành 2 nhánh như lông tơ. Quả 3 cạnh màu xám. ( Hình 6, Hm 1,3)",
#       "phan_bo_thu_hai_che_bien": "Cỏ gấu mọc hoang ở khắp nơi trên đồng ruộng, ven đường. Tại ven biển, đất cát xốp củ to hơn, dễ đào hơn. Đối với nhà nông, đây là một loại cỏ rất khó tiêu diệt. Chỉ cần sót lại một mẩu thân rễ nhỏ cũng đủ phát triển. Còn thấy mọc những ở nước khác vùng châu Á như\nTrung Quốc, Triều Tiên, Nhật Bản, Inđônêxia.\nThu hoạch củ gấu hiện nay chỉ mới dựa vào nguồn mọc hoang thiên nhiên; không ai trồng. Có thể kết hợp với việc làm cỏ vườn, ruộng để thu hoạch hay có thể tổ chức thu hái riêng.\nThường hay đào về mùa xuân, nhưng đào về mùa thu củ chắc và tốt hơn.\nSau khi đào toàn cây, người ta phơi cho khô, vun thành đống để đốt, lá và rễ con cháy hết, còn lại củ lấy riêng rửa sạch, phơi hay sấy khô.\nKhi dùng có thể dùng sống (nghĩa là củ chế biến như trên, dùng ngay), sắc hay ngâm rượu tán bột. Có thể chế biến thêm nữa. Các cụ lương y thường chế biến phức tạp rồi mới dùng. Theo kinh nghiệm của chúng tôi thì không cần chế biến gì thêm vẫn tốt.",
#       "thanh_phan_hoa_hoc": "Hoạt chất của hương phụ hiện chưa rõ. Chỉ mới biết trong hương phụ có từ 0,3 đến 2,8% tinh dầu màu vàng, mùi thơm nhẹ đặc biệt của hương phụ.\nThành phần tình dầu gồm 32% cyperen C15H24, 49% rượu cyperola C15H22O. Ngoài ra còn có các axit béo, phenol. Trong tinh dầu hương phụ Ấn Độ còn chứa cyperon C15H22O. Ngoài ra trong hương phụ còn chứa rất nhiều tinh bột.\nDo nguồn gốc hương phụ khác nhau, thành phần tinh dầu của hương phụ cũng không hoàn toàn giống nhau. Trong tinh dầu hương phụ Trung quốc có thành phần chủ yếu là cyperen (độ sôi 104°C/5mm thủy ngân) và izocyperotundone, còn trong tinh dầu hương phụ Nhật bản có thành phần chủ yếu là cyperol, cyperenol (độ chảy 94°C) chiếm 49%, cyperen 32% và a-cyperon (độ sôi 177°C/20mm thủy ngân), cyperotundon và cyperolon (độ chảy 41-42°C) (Lâm Khải Thọ, 1977, 580):",
#       "tac_dung_duoc_ly": "1. Theo Trương Phát Sơ, Trương Diệu Đức và Lưu Thiệu Quang (1935, Trung Hoa y học tạp chí tập 1, kỳ 2: 148-156) đã dùng vị hương phụ nguồn gốc ở tỉnh Quảng Đông, nhưng bán ở Nam Kinh chế thành cao lỏng 5%, tiến hành thí nghiệm 102 lần trên tử cung cô lập của thỏ, mèo, chó và chuột bạch đã chứng minh hương phụ có khả năng ức chế sự co bóp của tử cung, làm dịu sự căng thẳng của tử cung dù con vật có thai hay không có thai đều như nhau, gần như có tác dụng trực tiếp làm cho cơ tử cung dịu lại. So sánh tác dụng của cao lỏng hương phụ và cao lỏng đương quy (một vị thuốc bắc hiện nay còn phải nhập có tác dụng chữa bệnh phụ khoa) thì tác dụng giống nhau, nhưng tác dụng của đương quy mạnh hơn.\n2. Năm 1959, một số tác giả ở Quí Dương y học viện (Trung Quốc) báo cáo nghiên cứu và chứng minh tác dụng giảm đau trên chuột nhắt trắng.",
#       "tinh_vi": "Vị cay, hơi đắng, ngọt",
#       "quy_kinh": "Can và tam tiêu",
#       "cong_dung": "Chữa kinh nguyệt không đều, thấy kinh đau bụng, viêm tử cung mãn tính, các bệnh phụ nữ trước và sau khi sinh nở. Đau dạ dày do thần kinh, giúp sự tiêu hóa, ăn không tiêu, chữa nôn mửa, đau bụng, đi lỵ.",
#       "lieu_dung": "6-12g",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "NGẢI CỨU",
#       "ten_goi_khac": "cây thuốc cứu, cây thuốc cao, ngải điệp",
#       "ten_khoa_hoc": "Artemisia vulgaris L.",
#       "ho_thuc_vat": "Cúc Asteraceae (Compositae)",
#       "mo_ta": "Ngải cứu là một loại cỏ sống lâu năm, cao 50 60cm, thân to có rãnh dọc. Lá mọc so le, rộng, không có cuống (nhưng lá phía dưới thường có cuống), xẻ thùy lông chim, màu lá ở hai mặt rất khác nhau: Mặt trên nhẫn màu lục sẫm, mặt dưới màu trắng tro do có rất nhiều lông nhỏ, trắng. Hoa mọc thành chùy kép gồm rất nhiều cụm hoa hình đầu ( Hình 7).",
#       "phan_bo_thu_hai_che_bien": "Ngải cứu mọc hoang ở nhiều nơi trong nước ta, còn thấy mọc ở nhiều nước khác ở châu Á, cả châu Âu nữa. Ở nước ta một số gia đình trồng ngải cứu có tính chất quy mô nhỏ quanh nhà. Chưa thấy trồng quy mô lớn.\nThường hái cành và lá vào tháng 6 (gần tương ứng với tết mồng 5 tháng 5 âm lịch), phơi khô trong dâm mát. Có khi hái về phơi khô tán nhỏ, rây lấy phần lông trắng và tơi gọi là ngải nhung thường dùng làm mồi cứu.\nTrong phương pháp chữa bệnh bằng châm cứu, người ta có thể kích thích những huyệt hoặc bằng kim châm sâu vào da thịt, hoặc bằng cách đặt lên những huyệt một miếng gừng tươi mỏng có châm vài lỗ để tránh cho da thịt khỏi bị cháy bỏng nhưng hơi nóng vẫn ngắm tới da thịt rồi vê một nắm ngải nhung bằng một mồi thuốc lào đặt trên miếng gừng mà đốt; sức nóng kích thích huyệt (gọi là cứu). Sở dĩ người ta dùng lông ngải cứu vì nó có nhiều tinh dầu, cháy lâu không tắt.",
#       "thanh_phan_hoa_hoc": "Hiện nay hoạt chất của ngải cứu chưa được xác định, mặc dầu ngải cứu được dùng cả trong đông y và tây y. Chỉ mới biết trong ngải cứu có tinh dầu, ít tanin. Thành phần chủ yếu của tinh dầu ngải cứu là xineol và Q-thuyon. Ngoài ra còn một ít adenin, cholin.",
#       "tac_dung_duoc_ly": "Tinh dầu ngải cứu thuộc các tinh dầu có tính chất làm kích thích cho say.\na-thuyon có tác dụng hưng phấn, nhưng dùng nhiều quá có thể gây điên cuồng.\nNói chung tác dụng dược lý của ngải cứu ít thấy tài liệu nghiên cứu mặc dù ngải cứu được đưa vào Dược điển của nhiều nước trên thế giới, chủ yếu làm thuốc điều kinh.",
#       "tinh_vi": "Hơi ôn, vị cay",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Làm thuốc ôn khí huyết, trục hàn thấp, điều kinh, an thai, dùng chữa đau bụng do hàn, kinh nguyệt không đều, thai động không yên, thổ huyết, máu cam. Ngải cứu được dùng làm thuốc điều kinh: Một tuần lễ trước dự kỳ có kinh, uống mỗi ngày từ 6 đến 12g (tối đa 20g), sắc với nước hay hãm với nước sôi như hãm chè, chia làm 3 lần uống trong ngày. Có thể uống dưới dạng thuốc bột (5-10g) hay dưới dạng thuốc cao đặc 1-4g. Ngoài công dụng điều kinh, ngải cứu còn dùng làm thuốc giúp sự tiêu hóa, chữa đau bụng, nôn mửa, thuốc giun, sốt rét.",
#       "lieu_dung": "6-12g",
#       "ghi_chu": "Nếu có thai, thuốc không gây sẩy thai vì không có tác dụng kích thích đối với tử cung có thai."
#     },
#     {
#       "ten_viet_nam": "BẠCH ĐỒNG NỮ",
#       "ten_goi_khac": "bần trắng, vậy trắng, mấn trắng, mộ trắng",
#       "ten_khoa_hoc": "Clerodendron fragrans Vent.",
#       "ho_thuc_vat": "Cỏ roi ngựa (Verbenaceae)",

#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Lá bạch đồng nữ hay mò trắng thường chỉ hay dùng ngoài; không kể liều lượng người ta hái lá tươi về vò nát hay giã nát lấy nước hoặc sắc lấy nước dùng tắm ghẻ, mụn nhọt hay rửa chốc đầu . Dùng lá bạch đồng nữ sắc uống chữa bệnh khí hư, bạch đới",
#       "lieu_dung": "15-",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [
#     {
#       "ten_bai_thuoc": "Cao ích mẫu",
#       "chu_tri": "Không có thông tin",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Cây ích mẫu nấu với nước, cô đặc thành cao mềm."
#     },
#     {
#       "ten_bai_thuoc": "Cao hương ngải",
#       "chu_tri": "Chữa kinh nguyệt không đều, thấy kinh đau bụng, khó sinh nở, khí hư bạch đới.",
#       "nguon_goc": "Đỗ Tất Lợi xây dựng và đưa vào áp dụng rộng rãi đầu tiên vào năm 1946 với tên FUNUX, năm 1955 đổi thành CYPERIN.",
#       "ghi_chu": "Hương phụ, ngải cứu, ích mẫu, lá bạch đồng nữ mỗi thứ 1 g, thêm nước vào sắc kỹ, cô đến còn 10ml, thêm đường vào cho đủ ngọt. Đóng vào ống 10ml, hàn và hấp tiệt trùng (đun sôi và giữ sôi trong 1 giờ)."
#     }
#   ],
#   "cong_thuc": [
#     {
#       "ten_bai_thuoc": "Cao hương ngải",
#       "ten_vi_thuoc": "HƯƠNG PHỤ",
#       "lieu_luong": "1g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Cao hương ngải",
#       "ten_vi_thuoc": "NGẢI CỨU",
#       "lieu_luong": "1g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Cao hương ngải",
#       "ten_vi_thuoc": "ÍCH MẪU",
#       "lieu_luong": "1g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Cao hương ngải",
#       "ten_vi_thuoc": "BẠCH ĐỒNG NỮ",
#       "lieu_luong": "1g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     }
#   ]
# }
# ================================================================================
# 2025-11-21 15:37:24 - HerbExtractor - INFO - Extracted: 4 herbs, 2 prescriptions, 4 formulas
# 2025-11-21 15:37:28 - HerbExtractor - INFO -
# Processing text chunk 3/67
# 2025-11-21 15:37:28 - HerbExtractor - INFO - Pages 7-12: 26114 chars
# 2025-11-21 15:37:28 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 15:37:29 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 15:37:34 - HerbExtractor - INFO -
# Processing text chunk 4/67
# 2025-11-21 15:37:34 - HerbExtractor - INFO - Pages 10-15: 6106 chars
# 2025-11-21 15:37:34 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY XÀ SÀNG",
#       "ten_goi_khac": "cây giần sàng",
#       "ten_khoa_hoc": "Cnidium monnieri (L.) Cuss.",
#       "ho_thuc_vat": "Hoa tán Umbelliferae",
#       "mo_ta": "Cây xà sàng là một loại cỏ cao từ 0,4-1m. Thân có vạch dọc. Lá hai lần xẻ lông chim, chiều rộng của thùy 1-1,5mm. Cuống lá dài 4-8cm. Có bẹ lá ngắn. Hoa mọc thành tán kép. Tổng bao có ít lá bắc hẹp. Cuống hoa dài 7-12cm, dài hơn lá. Quả dài 2-5mm, có dìa mỏng (Hình 41).",
#       "phan_bo_thu_hai_che_bien": "Mọc hoang ở những nơi đất trống trong nước ta. Thu hái vào tháng 6 đến tháng 8 là thời gian quả chín. Nhổ hay cắt cả cây về phơi khô. Đập lấy quả. Loại bỏ tạp chất. Phơi lần nữa cho thật khô là được.",
#       "thanh_phan_hoa_hoc": "1. Tình đầu: Với tỷ lệ 1.3% có mùi hắc đặc biệt. Thành phần chủ yếu của tinh dầu là chất L. pinen, camphen và bocnylisovalerianat.\n2. Chất ostola tỉnh thể không màu có công thức C15H16O3, độ chảy 82°5-83°5.\n3. Chất dầu màu đen xanh có thành phần chủ yếu là 92,66% axit béo không no, 4,56% axit béo no và 0,38% chất không xà phòng hóa được, 3,27% glyxerin.\nCO\nCH3\nCH-CH=C\nCH3\nOstola",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Vị cay đắng, tính bình, hơi có độc",
#       "quy_kinh": "thận và tam tiêu",
#       "cong_dung": "Tác dụng cường dương, ích thận khử phong táo thấp, dùng chữa liệt dương, bộ phận sinh dục ẩm ngứa, phụ nữ lạnh tử cung, không có con, khí hư, xích bạch đới.",
#       "lieu_dung": "4 - 12",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY RAU MÁ LÁ RAU MUỐNG",
#       "ten_goi_khac": "hồng bối diệp; dương đề thảo; nhất điểm hồng; cây rau má lá rau muống cuống rau răm; tiết gà; tam tróc; rau chua lè; hoa mặt trời; lá mặt trời",
#       "ten_khoa_hoc": "Emilia sonchifolia (L) DC.",
#       "ho_thuc_vat": "Cúc Asteraceae (Compositae)",
#       "mo_ta": "Cây rau má lá rau muống là một loại cây nhỏ mọc hàng năm, thẳng đứng, cao 0,2-0,4cm thân nhẫn. Lá phía dưới hình mắt chim hay hình trứng có khi gốc hình tim, mép có răng cưa hay hơi chia thuỳ nhỏ, cuống dài, những lá sau hình 3 cạnh, chia lông chim, thuỳ tận cùng hình trứng hơi 3 cạnh, răng cưa to thô, lá ở trên hình 3 cạnh dài, không cuống, có tai và ôm vào thân. Cụm hoa hình đầu, hình trụ, dài 8-9mm, rộng 4mm, thường tụ 2-4 chiếc, cuống gầy, dài 3-6cm. Hoa màu hồng hay hơi tím. Quả bế dài 5,5mm, có gợn ngắn ( Hình 69 ).",
#       "phan_bo_thu_hai_che_bien": "Cây mọc hoang ở khắp bãi hoang, dọc bờ ruộng, hàng rào, ven đường. Còn thấy mọc ở các nước nhiệt đới châu Á và miền Nam Trung Quốc.\nDùng toàn cây (cành hoa lá) thu hái quanh năm. Hái về sao khô hoặc sao vàng.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Vị đặc biệt, hơi chua và hơi đắng",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Vị thuốc mới chỉ thấy dùng trong phạm vi nhân dân. Dùng tươi giã nát đắp chữa mụn nhọt, sắc uống để chữa ho lâu ngày, hoặc ho lao và chữa sốt.\nNước sắc dùng nhỏ mắt chữa đau mắt, nhỏ vào tai bị viêm, rửa mụn nhọt.",
#       "lieu_dung": "30-40",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "KÉ HOA VÀNG",
#       "ten_goi_khac": "kẻ đồng tiền; bạch bối hoàng hoa nhậm; chỗi đực; khát bo lương (Thái)",
#       "ten_khoa_hoc": "Sida rhombifolia L.",
#       "ho_thuc_vat": "Bông Malvaceae",
#       "mo_ta": "Cây nhỏ mọc thẳng đứng, cao 0,5-1m, thân và cành có nhiều lông ngắn hình sao. Lá hình trứng hay gần như hình trứng, đầu hơi nhọn ngắn, mép hơi răng cưa, dài 1,5-4cm, rộng 1-2,5cm, cuống dài 3-5mm, rất nhiều lông. Hoa màu vàng, mọc ở kẽ lá hay đầu cành. Đài hình chuông lá đài có lông màu trắng nhạt ở phía ngoài. Cánh trắng màu vàng cũng có lóng mịn. Nhị 20. Nhuy có 7 vòi. Quả có vỏ mỏng dễ vỡ, ở đỉnh có lông, phía lưng có hai vết nổi. Hạt cũng có lông.",
#       "phan_bo_thu_hai_che_bien": "Cây ké hoa vàng mọc hoang rất phổ biến ở khắp nơi trong nước ta, còn mọc ở Cămpuchia, Lào, Ấn Độ, Inđônêxia, Trung Quốc (miền Nam và Hải Nam), Malaixia.\nNgười ta hay hái lá cây để dùng tươi. Nhưng có khi hái lá hay toàn cây về phơi khô. Khi dùng có khi sao vàng để sắc uống. Có thể thu hái quanh năm, nhưng tốt nhất vào lúc cây đang ra hoa.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Nhân dân dùng làm thuốc mát uống trong các bệnh:\n- Mụn nhọt, tiểu tiện nóng đỏ hay vàng đậm, sốt, lỵ.",
#       "lieu_dung": "20",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "chu_tri": "tai ướt, ngứa",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Xà sàng tử, hoàng liên (hoặc hoàng đằng) mỗi vị 4g, khinh phấn (calômel)1g. Tán nhỏ trộn đều, thổi vào tai."
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "chu_tri": "Bạch đới khí hư",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Xà sàng tử, phèn chua, hai vị bằng nhau, tán nhỏ. Nấu hồ trộn vào làm thành viên bằng qua táo, bọc lụa hay gạc cho vào âm hộ.\nThấy nóng bỏ ra. Có thể sắc để thụt rửa."
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "chu_tri": "Lòi dom",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Xà sàng tử 40g, cam thảo 40g, tán nhỏ, trộn đều. Ngày uống 9g, chia ra làm 3 lần uống (mỗi lần 3g).\nĐồng thời nấu nước xà sàng tử xông và rửa chỗ đau."
#     }
#   ],
#   "cong_thuc": [
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "CÂY XÀ SÀNG",
#       "lieu_luong": "4",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "hoàng liên",
#       "lieu_luong": "4",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "hoàng đằng",
#       "lieu_luong": "4",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "khinh phấn",
#       "lieu_luong": "1",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "ten_vi_thuoc": "CÂY XÀ SÀNG",
#       "lieu_luong": "bằng nhau",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "ten_vi_thuoc": "phèn chua",
#       "lieu_luong": "bằng nhau",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "ten_vi_thuoc": "CÂY XÀ SÀNG",
#       "lieu_luong": "40",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "ten_vi_thuoc": "cam thảo",
#       "lieu_luong": "40",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     }
#   ]
# }
# ================================================================================
# 2025-11-21 15:37:51 - HerbExtractor - INFO - Extracted: 3 herbs, 3 prescriptions, 8 formulas
# 2025-11-21 15:37:56 - HerbExtractor - INFO -
# Processing text chunk 5/67
# 2025-11-21 15:37:56 - HerbExtractor - INFO - Pages 13-18: 2595 chars
# 2025-11-21 15:37:56 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY KEO GIẬU",
#       "ten_goi_khac": "cây bồ kết dại; cây muồng; cây táo nhân",
#       "ten_khoa_hoc": "Semen Leucaenae Glaucae",
#       "ho_thuc_vat": "Không có thông tin",
#       "mo_ta": "Cây keo hay bồ kết dại là một cây nhỡ không có gai, cao độ 2-4 m, hoặc hơn, lá 2 lần kép lông chim, có cuống chung dài 12-20cm, ở phía dưới phình lên và có một hạch ở dưới đuôi cuống phụ đầu tiên. Trên cuống có lông ngắn nằm rạp xuống. Lá chét từ 11-18 đôi, gần như không cuống, hình liềm, nhỏ ở đầu, dài 10-15mm, rộng 3-4mm. Hoa trắng nhiều, hợp thành hình cầu có cuống. Quả giáp dài 13-14cm, rộng 15mm, màu nâu, đầu có một mỏ nhọn cứng. Hạt có khoảng 15-20, hạt dẹt chỉ hơi phồng lên thôi, sắp nghiêng trong quả, dài 7mm rộng 4mm phẳng nhẵn, màu nâu nhạt, hình bầu dục, hơi lẹm ở phía dưới (Hình 113, Hm 7,2).",
#       "phan_bo_thu_hai_che_bien": "Cây keo dâu mọc hoang và được trồng khắp nơi trong nước ta để làm hàng rào, làm phân xanh bóng mát. Trâu bò rất thích ăn lá cây này. Khi quả chín lấy về đập lấy hạt phơi hay sấy khô. Ngoài công dụng làm thuốc, hạt còn đang được nghiên cứu làm thức ăn cho súc vật.",
#       "thanh_phan_hoa_hoc": "Được nhiều người nghiên cứu, sau đây là một số kết quả chính:\n1. Hạt không chứa tinh bột. Chứa 12-14% chất nhầy, chất đường, 4,45% tro, 21% protit, 5,5% chất béo và chất leuxenola (còn gọi là leuxenin hay mimosin) một chất đã tổng hợp được, có tính chất amino phenolic (Mascré, 1937 và Roger-Johnson J. L., 1949).\nChất leuxenola còn gọi là leuxenin C8H10O4N2, chứa trong lá và hạt với tỷ lệ 3% (trong lá khô) và 5% (chứa trong cây xấu hổ Mimosa pudica) giống nhau và hai chất như một (Vibau J. P., 1946). Chất leuxenin tan trong nước, trong cồn etylic và metylic, gần như không tan trong các dung môi hữu cơ khác, có tính chất độc.\nLeuxenola hydrat có độ chảy 291°, dạng khô kiệt có độ chảy 227-228°.\nCho muối clohydrat với độ chảy 179°5, muối iohydrat có độ chảy 183-183°5.\nNăng suất quay cực CD = -21° (H₂O).\n2. Theo Tôminaca (Nhật Bản 1949) trong lá còn chứa một chất glucozit.",
#       "tac_dung_duoc_ly": "Trẻ con thường ăn hạt keo xanh, không kể liều lượng, thấy có ra giun.\n1. Thời thuộc Pháp, hạt keo có được thí nghiệm dùng trị giun đũa ở bệnh viện đồn Thủy (cơ sở của bệnh viện 108 hiện nay) kết quả thấy có tác dụng trị giun với liều lượng 50g một ngày.\n2. Năm 1961, bệnh viện Ninh Giang có dùng trị giun cho 98 ca cũng đạt được kết quả tốt, không thấy có triệu chứng ngộ độc nào. Cách và liều dùng như sau:\nRang hạt cho đến khi nở, tán bột.\nTrẻ em 3-5 tuổi uống 5g một ngày uống luôn 3 ngày.\n- Trẻ em 6-10 tuổi uống 5g một ngày uống luôn 3 ngày.\nTrẻ em 11-15 tuổi uống 5g một ngày uống luôn 3 ngày.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 15:38:03 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 15:38:08 - HerbExtractor - INFO -
# Processing text chunk 6/67
# 2025-11-21 15:38:08 - HerbExtractor - INFO - Pages 16-21: 788 chars
# 2025-11-21 15:38:08 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 15:38:09 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 15:38:13 - HerbExtractor - INFO -
# Processing text chunk 7/67
# 2025-11-21 15:38:13 - HerbExtractor - INFO - Pages 19-24: 23584 chars
# 2025-11-21 15:38:13 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ...
#       "thanh_phan_hoa_hoc": "Vỏ thân và vỏ rễ chứa một ancaloit vị đắng, do Cornish lấy ra lần đầu tiên và được đặt tên là macgosin, có tác dụng diệt giun, ngoài ra còn",
#       "tac_dung_duoc_ly": "1. Tác dụng chữa giun.\n2. Tác dụng trên lâm sàng.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Vỏ rễ và vỏ thân xoan được nhân dân ta dùng chữa giun từ lâu đời nhưng vì có độc mà liều lượng dùng thường thiếu chính xác cho nên tuy có nhiều kết quả tốt nhưng cũng đã gây ra một số vụ ngộ độc.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 15:53:50 - HerbExtractor - INFO - Extracted: 2 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 15:53:54 - HerbExtractor - INFO -
# Processing text chunk 55/67
# 2025-11-21 15:53:54 - HerbExtractor - INFO - Pages 163-168: 4714 chars
# 2025-11-21 15:53:54 - HerbExtractor - INFO - API call 1/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#      11 print(f"Processing: {pdf_file}\n")
#      13 try:
# ---> 14     results = extractor.process_pdf_file(str(pdf_file))
#      16     end_time = datetime.now()
#      17     duration = (end_time - start_time).total_seconds()
#
# File ~/Projects/machine-learning/traditional_medicine/src/dataset.py:543, in DataExtractor.process_pdf_file(self, pdf_path)
#     539 self.logger.info(f"Pages {chunk_info['start_page']}-{chunk_info['end_page']}: "
#     540                f"{len(chunk_info['text'])} chars")
#     542 prompt = EXTRACTION_PROMPT.format(text=chunk_info['text'])
# --> 543 result = self._call_gemini_with_retry(prompt, chunk_info)
#     545 if result:
#     546     all_results['vi_thuoc'].extend(result.get('vi_thuoc', []))
#
# File ~/Projects/machine-learning/traditional_medicine/src/dataset.py:315, in DataExtractor._call_gemini_with_retry(self, prompt, chunk_info)
#     312 self.logger.info(f"API call {attempt + 1}/{self.settings.MAX_RETRIES}")
#     313 current_temperature = 0.0 if attempt == 0 else min(0.1 + (attempt * 0.15), 1.0)
# --> 315 response = self.gemini_client.models.generate_content(
#     316     model=self.settings.MODEL_NAME,
#     317     contents=prompt,
#     318     config=types.GenerateContentConfig(
#     319         temperature=current_temperature,
#     320         response_mime_type="application/json",
#     321         max_output_tokens=self.settings.MAX_OUTPUT_TOKENS,
#     322     )
#     323 )
#     324 # Parse and validate
#     325 print("="*80)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/google/genai/models.py:5076, in Models.generate_content(self, model, contents, config)
#    5074 while remaining_remote_calls_afc > 0:
#    5075   i += 1
# -> 5076   response = self._generate_content(
#    5077       model=model, contents=contents, config=parsed_config
#    5078   )
#    5080   function_map = _extra_utils.get_function_map(parsed_config)
#    5081   if not function_map:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/google/genai/models.py:3858, in Models._generate_content(self, model, contents, config)
#    3855 request_dict = _common.convert_to_dict(request_dict)
#    3856 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3858 response = self._api_client.request(
#    3859     'post', path, request_dict, http_options
#    3860 )
#    3862 if config is not None and getattr(
#    3863     config, 'should_return_http_response', None
#    3864 ):
#    3865   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1330, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1320 def request(
#    1321     self,
#    1322     http_method: str,
#    (...)   1325     http_options: Optional[HttpOptionsOrDict] = None,
#    1326 ) -> SdkHttpResponse:
#    1327   http_request = self._build_request(
#    1328       http_method, path, request_dict, http_options
#    1329   )
# -> 1330   response = self._request(http_request, http_options, stream=False)
#    1331   response_body = (
#    1332       response.response_stream[0] if response.response_stream else ''
#    1333   )
#    1334   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1166, in BaseApiClient._request(self, http_request, http_options, stream)
#    1163     retry = tenacity.Retrying(**retry_kwargs)
#    1164     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1166 return self._retry(self._request_once, http_request, stream)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1136, in BaseApiClient._request_once(self, http_request, stream)
#    1132   return HttpResponse(
#    1133       response.headers, response if stream else [response.text]
#    1134   )
#    1135 else:
# -> 1136   response = self._httpx_client.request(
#    1137       method=http_request.method,
#    1138       url=http_request.url,
#    1139       headers=http_request.headers,
#    1140       content=data,
#    1141       timeout=http_request.timeout,
#    1142   )
#    1143   errors.APIError.raise_for_response(response)
#    1144   return HttpResponse(
#    1145       response.headers, response if stream else [response.text]
#    1146   )
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Projects/machine-learning/traditional_medicine/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.12/ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File /usr/lib/python3.12/ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## **3. Load processed data**

# %%
print("Loading processed datasets...\n")

# Load all three datasets
df_vi_thuoc = pd.read_csv(settings.OUTPUT_CSV_VI_THUOC)
df_bai_thuoc = pd.read_csv(settings.OUTPUT_CSV_BAI_THUOC)
df_cong_thuc = pd.read_csv(settings.OUTPUT_CSV_CONG_THUC)

# Also load JSON for reference
with open(settings.OUTPUT_JSON, 'r', encoding='utf-8') as f:
    data_json = json.load(f)

print(f"Loaded {len(df_vi_thuoc):,} medicinal herbs")
print(f"Loaded {len(df_bai_thuoc):,} prescriptions")
print(f"Loaded {len(df_cong_thuc):,} formulas")

# %% [markdown]
# ## **4. Dataset dimensions and info**

# %%
datasets = {
    'Vị thuốc (Herbs)': df_vi_thuoc,
    'Bài thuốc (Prescriptions)': df_bai_thuoc,
    'Công thức (Formulas)': df_cong_thuc
}

for name, df in datasets.items():
    print(f"\n{name}:")
    print(f"Rows: {len(df):,}")
    print(f"Columns: {len(df.columns)}")
    print(f"Memory: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    print(f"Columns: {', '.join(df.columns.tolist())}")

# %%
def analyze_missing_data(df, name):
    print(f"\n{name}")
    print("-" * 60)
    
    missing = df.isnull().sum()
    missing_pct = (missing / len(df)) * 100
    
    missing_df = pd.DataFrame({
        'Column': missing.index,
        'Missing Count': missing.values,
        'Missing %': missing_pct.values
    }).sort_values('Missing %', ascending=False)
    
    # Filter only columns with missing data
    missing_df = missing_df[missing_df['Missing Count'] > 0]
    
    if len(missing_df) > 0:
        print(missing_df.to_string(index=False))
    else:
        print("✓ No missing values detected!")
    
    return missing_df

missing_herbs = analyze_missing_data(df_vi_thuoc, "Vị thuốc")
missing_prescriptions = analyze_missing_data(df_bai_thuoc, "Bài thuốc")
missing_formulas = analyze_missing_data(df_cong_thuc, "Công thức")
