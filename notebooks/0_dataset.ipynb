# %% [markdown]
# ## **0. Dataset Overview**
#
# Data extracted from Vietnamese Traditional Medicine documents include:
#
# 1. **Medicinal herbs**: Detailed information about Oriental medicine
#
# 2. **Prescriptions**: Traditional medicine
#
# 3. **Formulas**: Dosage and combination of medicinal herbs
#
# ## **Processing Pipeline**
#
# 1. PDF Chunking: Split 1300 pages into chunks of 200 pages/chunk with 30 pages overlap
# 2. Gemini API: Upload chunks and extract in groups of 8 pages with 3 pages overlap
# 3. Deduplication: Fuzzy matching with similarity threshold 0.85
# 4. Export: JSON + CSV format

# %% [markdown]
# ## **1. Import libraries**

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Setup plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)

# Add project root to path
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

# %%
from src.settings import settings
from src.dataset import DataExtractor

# %% [markdown]
# ## **2. Run extraction**

# %%
extractor = DataExtractor(
    settings=settings,
    logger_name="HerbExtractor",
    logger_path=f"{settings.LOG_PATH}/extraction.log"
)

pdf_file = f"{settings.RAW_DATA_PATH}/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf"

start_time = datetime.now()
print(f"Started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Processing: {pdf_file}\n")

try:
    results = extractor.process_pdf_file(str(pdf_file))
    
    end_time = datetime.now()
    duration = (end_time - start_time).total_seconds()
    
    print(f"Extraction completed successfully!")
    print(f"Duration: {duration/60:.1f} minutes ({duration:.0f} seconds)")
    print(f"Results saved to: {settings.PROCESSED_DATA_PATH}")
    
except Exception as e:
    print(f"Error during extraction: {e}")
    raise
# Out:
# Started at: 2025-11-21 18:24:12
# Processing: /home/qctrung/Projects/machine-learning/traditional_medicine/data/raw/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf
#
# 2025-11-21 18:24:12 - HerbExtractor - INFO - Processing: data/raw/sach-nhung-cay-thuoc-va-vi-thuoc-viet-nam.pdf
# 2025-11-21 18:24:12 - HerbExtractor - INFO - Model for OCR: gemini-2.0-flash-lite
# 2025-11-21 18:24:12 - HerbExtractor - INFO - Model for text extraction: gemini-2.5-flash-lite
# 2025-11-21 18:24:12 - HerbExtractor - INFO - Rate limit: 15 RPM
# 2025-11-21 18:24:13 - HerbExtractor - INFO - Created: chunk_000_pages_0001-0200.pdf (200 pages)
# 2025-11-21 18:24:14 - HerbExtractor - INFO - Created: chunk_001_pages_0171-0370.pdf (200 pages)
# 2025-11-21 18:24:14 - HerbExtractor - INFO - Created: chunk_002_pages_0341-0540.pdf (200 pages)
# 2025-11-21 18:24:14 - HerbExtractor - INFO - Created: chunk_003_pages_0511-0710.pdf (200 pages)
# 2025-11-21 18:24:15 - HerbExtractor - INFO - Created: chunk_004_pages_0681-0880.pdf (200 pages)
# 2025-11-21 18:24:15 - HerbExtractor - INFO - Created: chunk_005_pages_0851-1050.pdf (200 pages)
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Created: chunk_006_pages_1021-1220.pdf (200 pages)
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Created: chunk_007_pages_1191-1294.pdf (104 pages)
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Total chunks: 8
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Total pages: 1294
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Overlap: 30 pages between chunks
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Processing chunk 1/8: data/raw/chunk_000_pages_0001-0200.pdf
# 2025-11-21 18:24:16 - HerbExtractor - INFO - Uploading PDF: data/raw/chunk_000_pages_0001-0200.pdf
# 2025-11-21 18:24:20 - HerbExtractor - INFO - File uploaded successfully: files/x38mbqjx8di0
# 2025-11-21 18:24:20 - HerbExtractor - INFO - Processing PDF: 200 pages, 6 pages/chunk, 3 overlap
# 2025-11-21 18:24:52 - HerbExtractor - INFO - Pages 1-6: 5739 chars
# 2025-11-21 18:25:46 - HerbExtractor - INFO - Pages 4-9: 25822 chars
# 2025-11-21 18:26:21 - HerbExtractor - INFO - Pages 7-12: 1549 chars
# 2025-11-21 18:26:54 - HerbExtractor - INFO - Pages 10-15: 2290 chars
# 2025-11-21 18:27:35 - HerbExtractor - INFO - Pages 13-18: 6374 chars
# 2025-11-21 18:28:25 - HerbExtractor - INFO - Pages 16-21: 6406 chars
# 2025-11-21 18:29:08 - HerbExtractor - INFO - Pages 19-24: 13566 chars
# 2025-11-21 18:29:46 - HerbExtractor - INFO - Pages 22-27: 6506 chars
# 2025-11-21 18:30:34 - HerbExtractor - INFO - Pages 25-30: 13328 chars
# 2025-11-21 18:31:17 - HerbExtractor - INFO - Pages 28-33: 8868 chars
# 2025-11-21 18:31:49 - HerbExtractor - INFO - Pages 31-36: 2210 chars
# 2025-11-21 18:32:27 - HerbExtractor - INFO - Pages 34-39: 6335 chars
# 2025-11-21 18:33:01 - HerbExtractor - INFO - Pages 37-42: 2400 chars
# 2025-11-21 18:33:07 - HerbExtractor - WARNING - Rate limit hit, waiting 3.1s (retry 1/5)
# 2025-11-21 18:33:42 - HerbExtractor - INFO - Pages 40-45: 3454 chars
# 2025-11-21 18:33:48 - HerbExtractor - WARNING - Rate limit hit, waiting 2.9s (retry 1/5)
# 2025-11-21 18:34:24 - HerbExtractor - INFO - Pages 43-48: 5419 chars
# 2025-11-21 18:34:59 - HerbExtractor - INFO - Pages 46-51: 3174 chars
# 2025-11-21 18:35:31 - HerbExtractor - INFO - Pages 49-54: 2790 chars
# 2025-11-21 18:35:37 - HerbExtractor - WARNING - Rate limit hit, waiting 3.0s (retry 1/5)
# 2025-11-21 18:36:13 - HerbExtractor - INFO - Pages 52-57: 1069 chars
# 2025-11-21 18:36:54 - HerbExtractor - INFO - Pages 55-60: 5683 chars
# 2025-11-21 18:37:28 - HerbExtractor - INFO - Pages 58-63: 2368 chars
# 2025-11-21 18:38:04 - HerbExtractor - INFO - Pages 61-66: 3582 chars
# 2025-11-21 18:38:10 - HerbExtractor - WARNING - Rate limit hit, waiting 3.0s (retry 1/5)
# 2025-11-21 18:38:43 - HerbExtractor - INFO - Pages 64-69: 2380 chars
# 2025-11-21 18:39:20 - HerbExtractor - INFO - Pages 67-72: 5165 chars
# 2025-11-21 18:40:00 - HerbExtractor - INFO - Pages 70-75: 5665 chars
# 2025-11-21 18:40:06 - HerbExtractor - WARNING - Rate limit hit, waiting 2.9s (retry 1/5)
# 2025-11-21 18:40:10 - HerbExtractor - WARNING - Rate limit hit, waiting 4.6s (retry 2/5)
# 2025-11-21 18:40:42 - HerbExtractor - INFO - Pages 73-78: 2036 chars
# 2025-11-21 18:41:16 - HerbExtractor - INFO - Pages 76-81: 2548 chars
# 2025-11-21 18:41:54 - HerbExtractor - INFO - Pages 79-84: 2017 chars
# 2025-11-21 18:42:43 - HerbExtractor - INFO - Pages 82-87: 3096 chars
# 2025-11-21 18:43:18 - HerbExtractor - WARNING - Rate limit hit, waiting 3.1s (retry 1/5)
# 2025-11-21 18:43:22 - HerbExtractor - WARNING - Rate limit hit, waiting 4.7s (retry 2/5)
# 2025-11-21 18:43:55 - HerbExtractor - INFO - Pages 85-90: 2604 chars
# 2025-11-21 18:44:41 - HerbExtractor - INFO - Pages 88-93: 2713 chars
# 2025-11-21 18:45:18 - HerbExtractor - INFO - Pages 91-96: 3872 chars
# 2025-11-21 18:45:24 - HerbExtractor - WARNING - Rate limit hit, waiting 3.0s (retry 1/5)
# 2025-11-21 18:45:28 - HerbExtractor - WARNING - Rate limit hit, waiting 4.3s (retry 2/5)
# 2025-11-21 18:45:33 - HerbExtractor - WARNING - Rate limit hit, waiting 7.1s (retry 3/5)
# 2025-11-21 18:46:09 - HerbExtractor - INFO - Pages 94-99: 2017 chars
# 2025-11-21 18:46:37 - HerbExtractor - WARNING - Rate limit hit, waiting 2.9s (retry 1/5)
# 2025-11-21 18:46:42 - HerbExtractor - WARNING - Rate limit hit, waiting 4.4s (retry 2/5)
# 2025-11-21 18:47:17 - HerbExtractor - INFO - Pages 97-102: 1514 chars
# 2025-11-21 18:47:50 - HerbExtractor - INFO - Pages 100-105: 2137 chars
# 2025-11-21 18:48:22 - HerbExtractor - INFO - Pages 103-108: 1718 chars
# 2025-11-21 18:49:00 - HerbExtractor - INFO - Pages 106-111: 5510 chars
# 2025-11-21 18:49:07 - HerbExtractor - WARNING - Rate limit hit, waiting 3.1s (retry 1/5)
# 2025-11-21 18:49:12 - HerbExtractor - WARNING - Rate limit hit, waiting 4.6s (retry 2/5)
# 2025-11-21 18:49:18 - HerbExtractor - WARNING - Rate limit hit, waiting 6.8s (retry 3/5)
# 2025-11-21 18:49:26 - HerbExtractor - WARNING - Rate limit hit, waiting 9.7s (retry 4/5)
# 2025-11-21 18:50:03 - HerbExtractor - INFO - Pages 109-114: 1675 chars
# 2025-11-21 18:50:34 - HerbExtractor - INFO - Pages 112-117: 852 chars
# 2025-11-21 18:51:07 - HerbExtractor - INFO - Pages 115-120: 4044 chars
# 2025-11-21 18:51:41 - HerbExtractor - INFO - Pages 118-123: 2019 chars
# 2025-11-21 18:52:15 - HerbExtractor - INFO - Pages 121-126: 2192 chars
# 2025-11-21 18:52:20 - HerbExtractor - WARNING - Rate limit hit, waiting 3.1s (retry 1/5)
# 2025-11-21 18:52:52 - HerbExtractor - INFO - Pages 124-129: 896 chars
# 2025-11-21 18:53:29 - HerbExtractor - INFO - Pages 127-132: 3478 chars
# 2025-11-21 18:54:04 - HerbExtractor - INFO - Pages 130-135: 937 chars
# 2025-11-21 18:54:39 - HerbExtractor - INFO - Pages 133-138: 2000 chars
# 2025-11-21 18:55:09 - HerbExtractor - INFO - Pages 136-141: 1033 chars
# 2025-11-21 18:55:42 - HerbExtractor - INFO - Pages 139-144: 2030 chars
# 2025-11-21 18:56:14 - HerbExtractor - INFO - Pages 142-147: 1311 chars
# 2025-11-21 18:56:48 - HerbExtractor - INFO - Pages 145-150: 2014 chars
# 2025-11-21 18:57:21 - HerbExtractor - INFO - Pages 148-153: 1632 chars
# 2025-11-21 18:57:53 - HerbExtractor - INFO - Pages 151-156: 4054 chars
# 2025-11-21 18:58:26 - HerbExtractor - INFO - Pages 154-159: 2029 chars
# 2025-11-21 18:58:57 - HerbExtractor - INFO - Pages 157-162: 2442 chars
# 2025-11-21 18:59:32 - HerbExtractor - INFO - Pages 160-165: 1905 chars
# 2025-11-21 19:00:08 - HerbExtractor - INFO - Pages 163-168: 4470 chars
# 2025-11-21 19:00:41 - HerbExtractor - INFO - Pages 166-171: 1524 chars
# 2025-11-21 19:01:17 - HerbExtractor - INFO - Pages 169-174: 2030 chars
# 2025-11-21 19:01:53 - HerbExtractor - INFO - Pages 172-177: 548 chars
# 2025-11-21 19:02:33 - HerbExtractor - INFO - Pages 175-180: 4239 chars
# 2025-11-21 19:03:08 - HerbExtractor - INFO - Pages 178-183: 1954 chars
# 2025-11-21 19:03:40 - HerbExtractor - INFO - Pages 181-186: 3094 chars
# 2025-11-21 19:04:11 - HerbExtractor - INFO - Pages 184-189: 1057 chars
# 2025-11-21 19:04:48 - HerbExtractor - INFO - Pages 187-192: 2008 chars
# 2025-11-21 19:05:19 - HerbExtractor - INFO - Pages 190-195: 2114 chars
# 2025-11-21 19:05:50 - HerbExtractor - INFO - Pages 193-198: 2036 chars
# 2025-11-21 19:06:23 - HerbExtractor - INFO - Pages 196-200: 2062 chars
# 2025-11-21 19:06:57 - HerbExtractor - INFO - Pages 199-200: 2056 chars
# 2025-11-21 19:07:01 - HerbExtractor - INFO - Created 67 chunks from 200 pages
# 2025-11-21 19:07:01 - HerbExtractor - INFO -
# Processing text chunk 1/67
# 2025-11-21 19:07:01 - HerbExtractor - INFO - Pages 1-6: 5739 chars
# 2025-11-21 19:07:01 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:03 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:08 - HerbExtractor - INFO -
# Processing text chunk 2/67
# 2025-11-21 19:07:08 - HerbExtractor - INFO - Pages 4-9: 25822 chars
# 2025-11-21 19:07:08 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:09 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:14 - HerbExtractor - INFO -
# Processing text chunk 3/67
# 2025-11-21 19:07:14 - HerbExtractor - INFO - Pages 7-12: 1549 chars
# 2025-11-21 19:07:14 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:15 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:19 - HerbExtractor - INFO -
# Processing text chunk 4/67
# 2025-11-21 19:07:19 - HerbExtractor - INFO - Pages 10-15: 2290 chars
# 2025-11-21 19:07:19 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "ÍCH MẪU",
#       "ten_goi_khac": "ích mẫu thảo; sung úy; chói đèn",
#       "ten_khoa_hoc": "Leonurus heterophyllus Sw.",
#       "ho_thuc_vat": "Hoa môi Lamiaceae (Labiatae)",
#       "mo_ta": "Cây ích mẫu có tên như vậy vì có ích cho người mẹ (ích là có ích, mẫu là mẹ). Tên Leonurus do chữ Hy Lạp leon là sư tử, oura là đuôi, heterophyllus là lá có hình dạng biến đổi, vì cây ích mẫu giống đuôi con sư tử có lá hình dạng thay đổi. Ích mẫu là một loại cỏ sống 1-2 năm, cao 0,6m đến 1m. Thân hình vuông, ít phân nhánh, toàn thân có phủ lông nhỏ ngắn. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thô và sâu; lá ở thân có cuống ngắn hơn, phiến lá thường xẻ sâu thành 3 thùy, trên mỗi thùy lại có răng cưa thưa; lá trên cùng phần lớn không chia thùy và hầu như không cuống. Hoa mọc vòng ở kẽ lá. Tràng hoa màu hồng hay tím hồng, xẻ thành hai môi gần đều nhau. Quả nhỏ, 3 cạnh, vỏ màu xám nâu. Ngoài cây ích mẫu mô tả trên, cần chú ý phát hiện và phân biệt cây ích mẫu Leonurus sibiricus L. (tạm gọi là cây ích mẫu hoa to) vì cây này khác cây ích mẫu nói trên ở hoa to hơn, dài hơn, lá phía trên vẫn chia 3 thùy. Sự khác nhau giữa 2 cây: Lá trên cùng không chia thùy, tràng hoa dài 9-12mm, môi trên, môi dưới gần bằng nhau... Leonurus heterophyllus.",
#       "phan_bo_thu_hai_che_bien": "Không có thông tin",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:22 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:26 - HerbExtractor - INFO -
# Processing text chunk 5/67
# 2025-11-21 19:07:26 - HerbExtractor - INFO - Pages 13-18: 6374 chars
# 2025-11-21 19:07:26 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY DẦU GIUN",
#       "ten_goi_khac": "cây rau muối dại; cây cỏ hôi; cây thanh hao dại; thổ kinh giới",
#       "ten_khoa_hoc": "Chenopodium ambrosioides L. (Chenopodium anthelminticum A. Gray.)",
#       "ho_thuc_vat": "Chenopodiaceae",
#       "mo_ta": "Cây dầu giun là một loại cỏ sống hằng năm, nhưng cũng có khi ở đất tốt và cao ráo mọc 2-3 năm. Cao chừng 1m-1,5m hay hơn. Vỏ lá, thân và hoa có mùi hăng đặc biệt. Lá có cuống, mọc cách dài thon, một đầu nhọn, màu lục nhạt, phiến lá không phẳng, chung quanh có răng cưa thưa và không rõ rệt, dài chừng 35-75mm, rộng 13-25mm. Trên lá có lông, thường ở các gân lá, nhất là ở mặt dưới. Hoa mọc tập trung thành xim đơm (glomerule) ở kẽ lá. Giữa chùm là hoa đực hay hoa lưỡng tính, xung quanh có hoa cái nhỏ và không có cuống. Đường kính hoa độ 1mm, bao hoa có cánh hình bầu dục, hoa có 5 nhị, nhưng có khi chỉ có 3 hoặc 2, bầu hình bầu dục. Quả là những bế quả màu lục nhạt hay nâu nhạt, hình cầu, đường kính chừng 1,5mm, cùi mỏng, có lá đài không rụng, trong chứa một hạt nhỏ đen và bóng. Vị hắc đặc biệt. Thân cây non, lá, bầu hoa có lông thuộc 3 loại: lông che chở đa tế bào, lông che chở đa tế bào nhưng tế bào sau cùng lớn hơn, thành góc với các tế bào khác và lông bài tiết, chân ngắn gồm 1 hay 2 tế bào, tận cùng bằng một tế bào phồng to lên. Hái toàn cây và hạt để cất tinh dầu",
#       "phan_bo_thu_hai_che_bien": "Cây mọc tự nhiên ở nhiều nước vùng nhiệt đới, có mọc ở Châu Âu (vùng Địa Trung Hải). Tại Việt Nam mọc khắp Bắc Bộ, Trung Bộ, nhưng hình như tại Bắc Bộ mọc khỏe và dễ hơn các nơi. Hái toàn cây và hạt để cất tinh dầu",
#       "thanh_phan_hoa_hoc": "Trong cây dầu giun có 1,3% tinh dầu. Thành phần chủ yếu của tinh dầu là chất ascaridol (ít nhất phải có 65%). Tinh dầu của hoa và hạt có chứa nhiều hơn (trong các tháng 5, 6, 7, 8 tỷ lệ có thể lên tới 75-85%). Ngoài ra, còn chất ximen (22-35%) cacbua khác, ít campho, đimetyl etylen, oxyt, axit butylic và glycol. Chất ascaridol là một peroxyt có nhân para-ximen, rất dễ bị phá hủy khi cất tinh dầu. Giá trị của tinh dầu giun do tỷ lệ atcaridol quyết định.",
#       "tac_dung_duoc_ly": "1. Tác dụng trên mạch máu: Theo Hồ Thành Nho (Chiến thời y chính 3, 12-Trung văn, Khâu Thần Ba trích) rau sam có tác dụng làm co nhỏ mạch máu. Nguồn gốc tác dụng này do thần kinh trung ương và ngoại vi. 2. Tác dụng trên vì trùng: a. Theo báo cáo của Sở y học dự phòng Trung Quốc (Luận văn thứ 8 tháng 5-1943) nước sắc rau sam 25% có tác dụng ức chế sự phát dục của vi trùng lỵ Shiga-Kruse, vi trùng lỵ hình Y. Đối với trùng lỵ hình Y, tác dụng rất nhậy, từ nồng độ 10% trở lên đã có tác dụng. Đối với vi trùng thương hàn, nước sắc rau sam 25% cũng tỏ ra có tác dụng ức chế sự phát dục và tiêu diệt, nhưng thời gian so với vi trùng lỵ có kéo dài hơn. Thí nghiệm trên chó mắc bệnh, cho uống nước rau sam chưa thấy kết quả. Việc thí nghiệm tác dụng của rau sam trên cơ thể con vật bị lỵ còn gặp nhiều khó khăn. b. Năm 1953, theo Thực vật học báo, [2(2): 312-325] nghiên cứu tác dụng kháng sinh của 102 vị thuốc đông y, Vương Nhạc và cộng tác đã nhận thấy dịch chiết rau sam bằng cồn etylic có tác dụng rõ rệt trên trực khuẩn coli, trực trùng lỵ và trực trùng thương hàn.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa giun, chữa sán, chữa đau răng, chữa đi ngoài, chữa lỵ. Ngoài ra còn dùng để thuộc da, làm mực.",
#       "lieu_dung": "7-10g/ngày (dưới dạng thuốc sắc)",
#       "ghi_chu": "Vì thuốc này có độc, nên phải dùng cẩn thận. Uống vào sáng sớm lúc đói, uống 5 ngày liền, sau đó tẩy."
#     },
#     {
#       "ten_viet_nam": "CÂY KÉ ĐẦU NGỰA",
#       "ten_goi_khac": "thương nhĩ; phắt ma",
#       "ten_khoa_hoc": "Xanthium strumarium L.",
#       "ho_thuc_vat": "Cúc Asteraceae",
#       "mo_ta": "Cây ké đầu ngựa là một cây nhỏ, cao độ 2m thân có khía rãnh. Lá mọc so le, phiến lá hơi 3 cạnh, mép có răng cưa có chỗ khía hơi sâu thành 3-5 thùy, có lông ngắn cứng. Cụm hoa hình đầu có thứ lưỡng tính ở phía trên, có thứ chỉ gồm có hai hoa cái nằm trong hai lá bắc dày và có gai. Quả giả hình thoi, có móc, có thể móc vào lông động vật. Trẻ con vẫn nghịch bỏ vào tóc nhau rất khó gỡ ra (cắt đôi thấy ở trong có hai quả thực).",
#       "phan_bo_thu_hai_che_bien": "Cây ké này mọc hoang ở khắp nơi trong nước ta (đất hoang, bờ ruộng, bờ đường). Hái cả cây trừ bỏ rễ phơi hay sấy khô. Hoặc chỉ hái quả chín rồi phơi hay sấy khô.",
#       "thanh_phan_hoa_hoc": "Hiện nay chưa rõ hoạt chất của quả ké là gì. Mới biết rằng trong quả ké có chừng 30% chất béo, 1,27% một chất glucozit gọi là xanthostrumarin tương ứng với chất datixin, chưa rõ tính chất, 3,3% nhựa và vitamin C (Wehmer, 1931). Theo Xốcôlôv (1952) trong quả và cây ké ở Liên Xô đều chứa ancaloit nhưng theo sự phân tích của hệ được viện y học Bắc Kinh (1958) thì trong quả ké có một chất saponin (glucozit), không có ancaloit. Năm 1974, Khfagy (1974, Planta medica 8,75) đã tách từ trong ké một nhóm sesquitecpen chưa no, lacton có khung xanthonolit: xanthinin (độ chảy 123-124°), xanthanola và izoxanthanola. Quả Ké chứa: 1. Carboxy atractylozit ở dạng muối có tác dụng hạ đường huyết rất mạnh, có độc tính. 2. Xanthetin và xanthamin là những chất có tác dụng kháng khuẩn. Trong toàn cây có chứa nhiều iốt. Trong hai năm 1969 và 1970, Đỗ Tất Lợi, Phạm Kim Loan và Nguyễn Văn Cát (Trường đại học dược khoa Hà Nội) đã định tính và định lượng iốt trong cây ké Việt Nam thấy rằng dù cây ké mọc ở miền núi, hay đồng bằng, gần biển hay xa biển đều có chứa iốt với hàm lượng khá cao, 1g lá hoặc thân chứa trung bình 200 microgam, 1g qua chứa 220-230 microgam, nước sắc 15 phút cô thành cao chứa 300 microgam trong 1g cao: Nếu nấu lâu 5 giờ có thể chứa tới 420-430 microgam trong 1g cao: Trên cơ sở phân tích ấy đã đề nghị dùng ké trong điều trị bướu cổ. Tiêu chuẩn quy cách của Triều Tiên: Độ ẩm dưới 12%, độ tro 8%, tro không tan trong axit clohydric dưới 3%. Độ cao rượu ít nhất trên 8%.",
#       "tac_dung_duoc_ly": "Chưa thấy có tài liệu. Nhưng kinh nghiệm lâm sàng ở Sở da liễu Nam Xương-Giang Tây, 1959 đã sử dụng cao quả ké chữa 22 trường hợp bệnh ngoài da, kết qủa khỏi hẳn 11, đỡ rõ rệt 8, có tiến bộ 3, không có trường hợp nào không có",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa bệnh ngoài da.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:35 - HerbExtractor - INFO - Extracted: 2 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:39 - HerbExtractor - INFO -
# Processing text chunk 6/67
# 2025-11-21 19:07:39 - HerbExtractor - INFO - Pages 16-21: 6406 chars
# 2025-11-21 19:07:39 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:41 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:45 - HerbExtractor - INFO -
# Processing text chunk 7/67
# 2025-11-21 19:07:45 - HerbExtractor - INFO - Pages 19-24: 13566 chars
# 2025-11-21 19:07:45 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:47 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:52 - HerbExtractor - INFO -
# Processing text chunk 8/67
# 2025-11-21 19:07:52 - HerbExtractor - INFO - Pages 22-27: 6506 chars
# 2025-11-21 19:07:52 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:53 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:07:58 - HerbExtractor - INFO -
# Processing text chunk 9/67
# 2025-11-21 19:07:58 - HerbExtractor - INFO - Pages 25-30: 13328 chars
# 2025-11-21 19:07:58 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:07:59 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:04 - HerbExtractor - INFO -
# Processing text chunk 10/67
# 2025-11-21 19:08:04 - HerbExtractor - INFO - Pages 28-33: 8868 chars
# 2025-11-21 19:08:04 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "ÍCH MẪU",
#       "ten_goi_khac": "ích mẫu thảo; sung úy; chói đèn",
#       "ten_khoa_hoc": "Leonurus heterophyllus Sw.",
#       "ho_thuc_vat": "Họ Hoa môi Lamiaceae (Labiatae)",
#       "mo_ta": "Cây ích mẫu có tên như vậy vì có ích cho người mẹ (ích là có ích, mẫu là mẹ). Tên Leonurus do chữ Hy Lạp leon là sư tử, oura là đuôi, heterophyllus là lá có hình dạng biến đổi, vì cây ích mẫu giống đuôi con sư tử có lá hình dạng thay đổi. Ích mẫu là một loại cỏ sống 1-2 năm, cao 0,6m đến 1m. Thân hình vuông, ít phân nhánh, toàn thân có phủ lông nhỏ ngắn. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thô và sâu; lá ở thân có cuống ngắn hơn, phiến lá thường xẻ sâu thành 3 thùy, trên mỗi thùy lại có răng cưa thưa; lá trên cùng phần lớn không chia thùy và hầu như không cuống. Hoa mọc vòng ở kẽ lá. Tràng hoa màu hồng hay tím hồng, xẻ thành hai môi gần đều nhau. Quả nhỏ, 3 cạnh, vỏ màu xám nâu. Ngoài cây ích mẫu mô tả trên, cần chú ý phát hiện và phân biệt cây ích mẫu Leonurus sibiricus L. (tạm gọi là cây ích mẫu hoa to) vì cây này khác cây ích mẫu nói trên ở hoa to hơn, dài hơn, lá phía trên vẫn chia 3 thùy. Sự khác nhau giữa 2 cây: Lá trên cùng không chia thùy, tràng hoa dài 9-12mm, môi trên, môi dưới gần bằng nhau... Leonurus heterophyllus.",
#       "phan_bo_thu_hai_che_bien": "Không có thông tin",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:08:06 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:11 - HerbExtractor - INFO -
# Processing text chunk 11/67
# 2025-11-21 19:08:11 - HerbExtractor - INFO - Pages 31-36: 2210 chars
# 2025-11-21 19:08:11 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "ÍCH MẪU",
#       "ten_goi_khac": "ích mẫu thảo; sung úy; chói đèn",
#       "ten_khoa_hoc": "Leonurus heterophyllus Sw.",
#       "ho_thuc_vat": "Họ Hoa môi Lamiaceae (Labiatae)",
#       "mo_ta": "Cây ích mẫu có tên như vậy vì có ích cho người mẹ (ích là có ích, mẫu là mẹ). Tên Leonurus do chữ Hy Lạp leon là sư tử, oura là đuôi, heterophyllus là lá có hình dạng biến đổi, vì cây ích mẫu giống đuôi con sư tử có lá hình dạng thay đổi. Ích mẫu là một loại cỏ sống 1-2 năm, cao 0,6m đến 1m. Thân hình vuông, ít phân nhánh, toàn thân có phủ lông nhỏ ngắn. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thô và sâu; lá ở thân có cuống ngắn hơn, phiến lá thường xẻ sâu thành 3 thùy, trên mỗi thùy lại có răng cưa thưa; lá trên cùng phần lớn không chia thùy và hầu như không cuống. Hoa mọc vòng ở kẽ lá. Tràng hoa màu hồng hay tím hồng, xẻ thành hai môi gần đều nhau. Quả nhỏ, 3 cạnh, vỏ màu xám nâu. Ngoài cây ích mẫu mô tả trên, cần chú ý phát hiện và phân biệt cây ích mẫu Leonurus sibiricus L. (tạm gọi là cây ích mẫu hoa to) vì cây này khác cây ích mẫu nói trên ở hoa to hơn, dài hơn, lá phía trên vẫn chia 3 thùy. Sự khác nhau giữa 2 cây: Lá trên cùng không chia thùy, tràng hoa dài 9-12mm, môi trên, môi dưới gần bằng nhau... Leonurus heterophyllus",
#       "phan_bo_thu_hai_che_bien": "Không có thông tin",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:08:14 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:18 - HerbExtractor - INFO -
# Processing text chunk 12/67
# 2025-11-21 19:08:18 - HerbExtractor - INFO - Pages 34-39: 6335 chars
# 2025-11-21 19:08:18 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:08:19 - HerbExtractor - INFO - Extracted: 0 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:24 - HerbExtractor - INFO -
# Processing text chunk 13/67
# 2025-11-21 19:08:24 - HerbExtractor - INFO - Pages 37-42: 2400 chars
# 2025-11-21 19:08:24 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "BỒ CÔNG ANH",
#       "ten_goi_khac": "bồ công anh; rau bồ cóc; diếp hoang; diếp dại; mót mét; mũi mác; diếp trời; rau mũi cày",
#       "ten_khoa_hoc": "Lactuca indica L.",
#       "ho_thuc_vat": "Cúc Asteraceae",
#       "mo_ta": "Bồ công anh là một cây nhỏ, cao 0,60m đến 1m, có thể cao tới 3m. Thân mọc thẳng, nhẫn, không cành hoặc rất ít cành. Lá có nhiều hình dạng; lá phía dưới dài 30cm, rộng 5-6cm. gần như không cuống, chia thành nhiều thùy hay răng cưa to thô, lá phía trên ngắn hơn, nguyên chứ không chia thùy, mép có răng cưa thưa. Bấm lá và thân đều thấy tiết ra nhũ dịch màu trắng đục như sữa, vị hơi đắng. Cụm hoa hình đầu, màu vàng, có loại tím.",
#       "phan_bo_thu_hai_che_bien": "Không có thông tin",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY BỒ CÔNG ANH TRUNG QUỐC",
#       "ten_goi_khac": "hoàng hoa địa đính; nãi chấp thảo",
#       "ten_khoa_hoc": "Taraxacum officinale Wigg.",
#       "ho_thuc_vat": "Cúc Asteraceae",
#       "mo_ta": "Không có thông tin",
#       "phan_bo_thu_hai_che_bien": "Ở Trung Quốc, dùng với tên bồ công anh hoặc là toàn cây cả rễ, hoặc là rễ tươi hay phơi hoặc sấy khô của nhiều loài bồ công anh như Taraxacum mongolicum Hand-Mazz., Taraxacum sinicum Kitag., Taraxacum heterolepis Nakai et H. Koidz. hoặc một số loài khác giống, cùng họ.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Cây này ít thấy dùng ở Việt Nam. Nhưng lại rất phổ biến và được dùng tại các nước."
#     }
#   ],
#   "bai_thuoc": [
#     {
#       "ten_bai_thuoc": "Bồ công anh chữa sưng vú, tắc tia sữa",
#       "chu_tri": "Sưng vú, tắc tia sữa",
#       "nguon_goc": "Kinh nghiệm dân gian",
#       "ghi_chu": "Hái 20 đến 40g lá bồ công anh tươi, rửa sạch, thêm ít muối giã nát, vắt lấy nước uống, bã dùng đắp lên nơi vú sưng đau. Thường chỉ dùng 2-3 lần là đỡ."
#     },
#     {
#       "ten_bai_thuoc": "Bồ công anh chữa ăn uống kém tiêu, hay bị mụn nhọt",
#       "chu_tri": "Ăn uống kém tiêu, hay bị mụn nhọt",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Lá bồ công anh khô 10 đến 15g; nước 600ml (3 bát), sắc còn 200ml (1 bát) (có thể đun sôi kỹ và giữ sôi trong vòng 15 phút). Uống liên tục trong 3-5 ngày, có thể kéo dài hơn."
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc chữa đau dạ dày",
#       "chu_tri": "Đau dạ dày",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Thêm 300ml nước, sắc đun sôi trong vòng 15 phút, thêm ít đường vào mà uống (chia 3 lần uống trong ngày). Uống liên tục trong vòng 10 ngày, nghỉ 3 ngày rồi lại tiếp tục cho đến khi khỏi."
#     }
#   ],
#   "cong_thuc": [
#     {
#       "ten_bai_thuoc": "Bồ công anh chữa ăn uống kém tiêu, hay bị mụn nhọt",
#       "ten_vi_thuoc": "BỒ CÔNG ANH",
#       "lieu_luong": "10-15g",
#       "vai_tro": "Chủ trị",
#       "ghi_chu_che_bien": "Dạng khô, sắc với nước"
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc chữa đau dạ dày",
#       "ten_vi_thuoc": "BỒ CÔNG ANH",
#       "lieu_luong": "20g",
#       "vai_tro": "Chủ trị",
#       "ghi_chu_che_bien": "Dạng khô, sắc với nước, thêm đường"
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc chữa đau dạ dày",
#       "ten_vi_thuoc": "lá khôi",
#       "lieu_luong": "15g",
#       "vai_tro": "Phối hợp",
#       "ghi_chu_che_bien": "Dạng khô, sắc với nước, thêm đường"
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc chữa đau dạ dày",
#       "ten_vi_thuoc": "lá khổ sâm",
#       "lieu_luong": "10g",
#       "vai_tro": "Phối hợp",
#       "ghi_chu_che_bien": "Dạng khô, sắc với nước, thêm đường"
#     }
#   ]
# }
# ================================================================================
# 2025-11-21 19:08:30 - HerbExtractor - INFO - Extracted: 2 herbs, 3 prescriptions, 4 formulas
# 2025-11-21 19:08:34 - HerbExtractor - INFO -
# Processing text chunk 14/67
# 2025-11-21 19:08:34 - HerbExtractor - INFO - Pages 40-45: 3454 chars
# 2025-11-21 19:08:34 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "ÍCH MẪU",
#       "ten_goi_khac": "ích mẫu thảo; sung úy; chói đèn",
#       "ten_khoa_hoc": "Leonurus heterophyllus Sw.",
#       "ho_thuc_vat": "Hoa môi Lamiaceae (Labiatae)",
#       "mo_ta": "Cây ích mẫu có tên như vậy vì có ích cho người mẹ (ích là có ích, mẫu là mẹ). Tên Leonurus do chữ Hy Lạp leon là sư tử, oura là đuôi, heterophyllus là lá có hình dạng biến đổi, vì cây ích mẫu giống đuôi con sư tử có lá hình dạng thay đổi. Ích mẫu là một loại cỏ sống 1-2 năm, cao 0,6m đến 1m. Thân hình vuông, ít phân nhánh, toàn thân có phủ lông nhỏ ngắn. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thô và sâu; lá ở thân có cuống ngắn hơn, phiến lá thường xẻ sâu thành 3 thùy, trên mỗi thùy lại có răng cưa thưa; lá trên cùng phần lớn không chia thùy và hầu như không cuống. Hoa mọc vòng ở kẽ lá. Tràng hoa màu hồng hay tím hồng, xẻ thành hai môi gần đều nhau. Quả nhỏ, 3 cạnh, vỏ màu xám nâu. Ngoài cây ích mẫu mô tả trên, cần chú ý phát hiện và phân biệt cây ích mẫu Leonurus sibiricus L. (tạm gọi là cây ích mẫu hoa to) vì cây này khác cây ích mẫu nói trên ở hoa to hơn, dài hơn, lá phía trên vẫn chia 3 thùy. Sự khác nhau giữa 2 cây: 1. Lá trên cùng không chia thùy, tràng hoa dài 9-12mm, môi trên, môi dưới gần bằng nhau... Leonurus heterophyllus. 2. Lá trên cùng xẻ 3 thùy, tràng hoa dài 15-20mm, môi dưới ngắn hơn môi trên... Leonurus sibiricus L.",
#       "phan_bo_thu_hai_che_bien": "Ích mẫu hiện nay chủ yếu mọc hoang, thường thấy ở ven suối, ven sông nơi đất cát, còn mọc hoang ở ruộng hoang, ven đường. Gần đây một số nơi đã bắt đầu trồng để làm thuốc. Kinh nghiệm trồng ích mẫu: Ích mẫu mùa đông cần trồng vào mùa thu, ích mẫu mùa xuân gieo trồng vào mùa xuân hay mùa thu, ích mẫu mùa hạ cũng có thể gieo trồng vào mùa xuân hay mùa thu. Ích mẫu mùa hạ cho hiệu suất cao nhất (9 tấn khô 1 hecta), nhưng thời gian từ khi gieo đến khi thu hoạch trên 10 tháng, còn các loài mùa đông và mùa xuân chỉ cần hơn 8 tháng nhưng năng suất chỉ được 4-6 tấn khô 1 hecta. Gieo hạt thẳng thành luống, mỗi luống cách nhau 17cm, trên mỗi luống cây nọ cách cây kia 7cm cho sản lượng cao nhất. Mỗi hecta cần từ 8 đến 9 kilôgam hạt giống. Khi trồng cần trộn hạt với tro bếp. Vào khoảng tháng 5-6, lúc một nửa số hoa của cây bắt đầu",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:08:39 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:43 - HerbExtractor - INFO -
# Processing text chunk 15/67
# 2025-11-21 19:08:43 - HerbExtractor - INFO - Pages 43-48: 5419 chars
# 2025-11-21 19:08:43 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY HOA CỨT LỢN",
#       "ten_goi_khac": "cây hoa ngũ sắc; cây hoa ngũ vị; cỏ hôi",
#       "ten_khoa_hoc": "Ageratum conyzoides L.",
#       "ho_thuc_vat": "Cúc Asteraceae",
#       "mo_ta": "Cây hoa cứt lợn là một cây nhỏ, mọc hàng năm, thân có nhiều lông nhỏ mềm, cao chừng 25-50cm, mọc hoang ở khắp nơi trong nước ta. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thưa.\nHoa nhỏ, màu tím, xanh. Quả bế màu đen, có 5 sống dọc (Hình 14).",
#       "phan_bo_thu_hai_che_bien": "Không có thông tin",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa mụn nhọt, mẩn ngứa, sốt, cảm.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Cần chú ý nghiên cứu."
#     },
#     {
#       "ten_viet_nam": "RAU SAM",
#       "ten_goi_khac": "mã xỉ hiện; pourpier",
#       "ten_khoa_hoc": "Portulaca oleracea L.",
#       "ho_thuc_vat": "Rau sam Portulacaceae",
#       "mo_ta": "Rau sam là một loại cỏ sống hàng năm, có nhiều cành mẫm, nhẵn. Thân có màu đỏ nhạt, dài 10 đến 30cm. Lá hình bầu dục dài, phía đáy lá hơi thót lại, không cuống, phiến lá dày, mặt bóng, dài 2cm, rộng 8-14mm. Những lá phía trên họp thành một thứ tổng bao quanh các hoa.\nQuả nang bình cầu, mở bằng 1 nắp. Trong có chứa nhiều hạt màu đen bóng (hình 127).",
#       "phan_bo_thu_hai_che_bien": "Rau sam mọc hoang ở khắp những nơi ẩm ướt của nước ta. Còn thấy mọc ở nhiều nước khác như Trung Quốc, Nhật Bản, Ấn Độ, Châu Âu. Tại nhiều nước châu Âu, nhất là ở Pháp, người ta trồng làm rau ăn, vị chua dễ chịu gọi là pourpier.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa mụn nhọt, mẩn ngứa, ho, hen, xuyễn, thông kinh nguyệt, lợi tiểu tiện.",
#       "lieu_dung": "Dùng ngoài không kể liều lượng.",
#       "ghi_chu": "Cần theo dõi."
#     },
#     {
#       "ten_viet_nam": "CÂY GAI",
#       "ten_goi_khac": "gai; cây gai dầu; cây gai",
#       "ten_khoa_hoc": "Boehmeria nivea (L.) Gaud.",
#       "ho_thuc_vat": "Gai Urticaceae",
#       "mo_ta": "Cây sống lâu năm, cao 2,5-5m. Thân cành, lá phủ lông trắng. Lá hình trứng, mép có răng cưa. Hoa mọc thành bông ở kẽ lá.",
#       "phan_bo_thu_hai_che_bien": "Cây gai mọc hoang ở nhiều nơi trong nước ta. Người ta dùng lá và rễ tươi làm thuốc.",
#       "thanh_phan_hoa_hoc": "Chưa thấy tài liệu nghiên cứu.",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa bệnh ngoài da.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY BÔNG",
#       "ten_goi_khac": "cây bông; bông vải",
#       "ten_khoa_hoc": "Gossypium sp.",
#       "ho_thuc_vat": "Bông Malvaceae",
#       "mo_ta": "Cây bông là một cây nhỡ, cao 0,5-1m, thân có lông. Lá hình tim, xẻ thùy. Hoa màu vàng. Quả nang.",
#       "phan_bo_thu_hai_che_bien": "Trồng ở nhiều nơi.",
#       "thanh_phan_hoa_hoc": "Trong hạt bông có chừng 17-30% dầu, nếu chỉ tính nhân không tỷ lệ lên tới 35-40%. Dầu bông ép nguội có màu vàng nhạt, không mùi vị, có chứa sinh tố E.",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Làm thuốc lợi sữa.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY NGƯU TẤT",
#       "ten_goi_khac": "cỏ xước; hoài ngưu tất",
#       "ten_khoa_hoc": "Achyranthes bidentata Blume.",
#       "ho_thuc_vat": "Giền Amaranthaceae",
#       "mo_ta": "Cây ngưu tất là một loại cỏ xước cho nên người ta nhầm với cây cỏ xước Achyranthes aspera L. Cỏ có thân mảnh, hơi vuông, thường chỉ cao 1m, cũng có khi tới 2m. Lá mọc đối có cuống, dài 5-12cm, rộng 2-4cm, phiến lá hình trứng, đầu nhọn, mép nguyên. Cụm hoa mọc thành bông ở kẽ lá.",
#       "phan_bo_thu_hai_che_bien": "Hiện nay ta còn phải nhập của Trung Quốc. Tại Trung Quốc, liêu cảo bản chủ sản ở Hà Bắc, rồi đến Sơn Tây, Liêu Ninh, Cát Lâm, Nội Mông. Loại này vừa dùng trong nước, vừa để xuất khẩu một ít.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Viêm khớp, đau bụng, kinh nguyệt khó khăn.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY DIẾP CÁ",
#       "ten_goi_khac": "cây lá giấp; ngư tinh thảo",
#       "ten_khoa_hoc": "Houttuynia cordata Thunb.",
#       "ho_thuc_vat": "Lá giấp Saururaceae",
#       "mo_ta": "Cây diếp cá là một loại cỏ nhỏ, mọc lâu năm, ưa chỗ ẩm ướt có thân rễ mọc ngầm dưới đất. Rễ nhỏ mọc ở các đốt, thân mọc đứng cao 40cm, có lông hoặc ít lông. Lá mọc cách, hình tim, đầu lá, hơi nhọn hay nhọn hẳn. Hoa nhỏ màu vàng nhạt, không có bao hoa, mọc thành bông, có 4 lá bắc màu trắng; trông toàn bộ bề ngoài của cụm hoa và lá bắc giống như một cây hoa đơn độc, toàn cây vò có mùi tanh như cá. Hoa nở về mùa hạ vào các tháng 5-8 (Hình 11).",
#       "phan_bo_thu_hai_che_bien": "Ngải cứu mọc hoang ở khắp nơi trong nước ta, còn thấy mọc ở nhiều nước khác ở châu Á, cả châu Âu nữa. Ở nước ta một số gia đình trồng ngải cứu có tính chất quy mô nhỏ quanh nhà. Chưa thấy trồng quy mô lớn.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Cay, hơi lạnh, hơi có độc, vào phế kinh.",
#       "quy_kinh": "Phế kinh",
#       "cong_dung": "Tán nhiệt, tiêu ung thũng, dùng chữa phế ung, ngoài dùng chữa ung thũng, trĩ, vết lở loét. Chữa mụn nhọt, mẩn ngứa, sốt, cảm. Chữa sưng vú, tắc tia sữa. Chữa bệnh đau dạ dày, ăn uống kém tiêu.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "CÂY BÔNG",
#       "ten_goi_khac": "cây bông; bông vải",
#       "ten_khoa_hoc": "Malva verticillata L.",
#       "ho_thuc_vat": "Bông Malvaceae",
#       "mo_ta": "Cây thảo, cao 0,5-1m. Lá hình tròn, mép có răng cưa. Hoa mọc ở kẽ lá, màu trắng hay hồng.",
#       "phan_bo_thu_hai_che_bien": "Trồng ở nhiều nơi.",
#       "thanh_phan_hoa_hoc": "Không có thông tin",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Chữa ho, lợi tiểu.",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:08:53 - HerbExtractor - INFO - Extracted: 7 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:08:57 - HerbExtractor - INFO -
# Processing text chunk 16/67
# 2025-11-21 19:08:57 - HerbExtractor - INFO - Pages 46-51: 3174 chars
# 2025-11-21 19:08:57 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY DIẾP CÁ",
#       "ten_goi_khac": "diếp cá; lá giấp; ngư tinh thảo",
#       "ten_khoa_hoc": "Houttuynia cordata Thunb.",
#       "ho_thuc_vat": "Saururaceae",
#       "mo_ta": "Cây diếp cá là một loại cỏ nhỏ, mọc lâu năm, ưa chỗ ẩm ướt có thân rễ mọc ngầm dưới đất. Rễ nhỏ mọc ở các đốt, thân mọc đứng cao 40cm, có lông hoặc ít lông. Lá mọc đối, tùy theo lá mọc ở gốc, giữa thân hay đầu cành mà có hình dạng khác nhau. Lá ở gốc, có cuống dài, phiến lá hình tim, mép có răng cưa thô và sâu; lá ở thân có cuống ngắn hơn, phiến lá thường xẻ sâu thành 3 thùy, trên mỗi thùy lại có răng cưa thưa; lá trên cùng phần lớn không chia thùy và hầu như không cuống. Hoa mọc vòng ở kẽ lá. Tràng hoa màu hồng hay tím hồng, xẻ thành hai môi gần đều nhau. Quả nhỏ, 3 cạnh, vỏ màu xám nâu.",
#       "phan_bo_thu_hai_che_bien": "Ích mẫu hiện nay chủ yếu mọc hoang, thường thấy ở ven suối, ven sông nơi đất cát, còn mọc hoang ở ruộng hoang, ven đường. Gần đây một số nơi đã bắt đầu trồng để làm thuốc.",
#       "thanh_phan_hoa_hoc": "Chưa thấy tài liệu nghiên cứu.",
#       "tac_dung_duoc_ly": "1. Tác dụng trên tử cung. Nước sắc ích mẫu Leonurus sibiricus 1/5.000 hay 1/1.000 có tác dụng kích thích đối với tử cung cô lập của thỏ cái (dù có thai hay không có thai cũng vậy). Thỏ cái gây mê bằng urêtan rồi cho uống nước sắc ích mẫu cũng thấy có tác dụng kích thích trên tử cung tại chỗ của thỏ. Dung dịch nước 10% ích mẫu khô tác dụng trên tử cung mạnh hơn là dung dịch rượu 20%. Tác dụng của ích mẫu trên tử cung cũng giống như tác dụng của cựa lõa mạch (Claviceps purpurea). Điều đáng chú ý là dùng dung dịch rượu hay dung dịch nước ích mẫu tác dụng lên tử cung thì bắt đầu có một giai đoạn hưng phấn. Nếu trước khi sắc ích mẫu, dùng ête để loại phần tan trong ête đi thì hiện tượng ức chế tử cung không thấy nữa. 2. Tác dụng trên huyết áp. Nước sắc ích mẫu tuy không tác dụng trực tiếp trên huyết áp nhưng làm giảm tác dụng của adrenalin trên mạch máu, Cao ích mẫu làm giảm huyết áp, nhất là đối với thời kỳ đầu của bệnh cao huyết áp. 3. Tác dụng trên tim mạch. Loài ích mẫu Leonurus quinquelobatus và Leonurus cardia có tác dụng tốt trên tim mạch và đối với cơ tim có bệnh. 4. Tác dụng đối với hệ thần kinh của ích mẫu Leonurus sibiricus mạnh hơn tác dụng của Vale-rian và của Muyghe (Convallaria maialis). 5. Tác dụng kháng sinh đối với một số vi trùng ngoài da. Theo Trung Hoa bì phụ khoa tạp chí (số 4-1957, tr. 286-292) một số tác giả nghiên cứu thấy nước chiết ích mẫu 1 : 4 có tác dụng ức chế với trình độ khác nhau đối với một số vi trùng gây bệnh ngoài da. 6. Tác dụng trên viêm thận và phù cấp tính.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:09:01 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:09:06 - HerbExtractor - INFO -
# Processing text chunk 17/67
# 2025-11-21 19:09:06 - HerbExtractor - INFO - Pages 49-54: 2790 chars
# 2025-11-21 19:09:06 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "CÂY DẦU GIUN",
#       "ten_goi_khac": "cây dầu giun; cây cỏ hôi; cây thanh hao dại; thổ kinh giới",
#       "ten_khoa_hoc": "Chenopodium ambrosioides L. (Chenopodium anthelminticum A. Gray.)",
#       "ho_thuc_vat": "Chenopodiaceae",
# ...
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Vị đắng, cay, tính ôn",
#       "quy_kinh": "Vào 2 kinh thận và tam tiêu",
#       "cong_dung": "Tác dụng cường dương, ích thận khử phong táo thấp, dùng chữa liệt dương, bộ phận sinh dục ẩm ngứa, phụ nữ lạnh tử cung, không có con, khí hư, xích bạch đới. Nhân dân thường dùng cây dầu giun để chữa giun đũa, giun kim và sán.",
#       "lieu_dung": "4 - 12g dưới dạng thuốc sắc uống riêng hoặc phối hợp với các vị thuốc khác.",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "chu_tri": "Tai ướt, ngứa",
#       "nguon_goc": "Đơn thuốc có xà sàng tử",
#       "ghi_chu": "Xà sàng tử, hoàng liên (hoặc hoàng đằng) mỗi vị 4g, khinh phấn (calômel)1g. Tán nhỏ trộn đều, thổi vào tai."
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "chu_tri": "Bạch đới khí hư",
#       "nguon_goc": "Đơn thuốc có xà sàng tử",
#       "ghi_chu": "Xà sàng tử, phèn chua, hai vị bằng nhau, tán nhỏ. Nấu hồ trộn vào làm thành viên bằng qua táo, bọc lụa hay gạc cho vào âm hộ. Thấy nóng bỏ ra. Có thể sắc để thụt rửa."
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "chu_tri": "Lòi dom",
#       "nguon_goc": "Đơn thuốc có xà sàng tử",
#       "ghi_chu": "Xà sàng tử 40g, cam thảo 40g, tán nhỏ, trộn đều. Ngày uống 3 lần."
#     }
#   ],
#   "cong_thuc": [
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "Xà sàng tử",
#       "lieu_luong": "4g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ"
#     },
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "Hoàng liên",
#       "lieu_luong": "4g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ"
#     },
#     {
#       "ten_bai_thuoc": "Chữa tai ướt, ngứa",
#       "ten_vi_thuoc": "Khinh phấn",
#       "lieu_luong": "1g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ"
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "ten_vi_thuoc": "Xà sàng tử",
#       "lieu_luong": "Bằng nhau",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ, nấu hồ trộn vào làm thành viên"
#     },
#     {
#       "ten_bai_thuoc": "Bạch đới khí hư",
#       "ten_vi_thuoc": "Phèn chua",
#       "lieu_luong": "Bằng nhau",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ, nấu hồ trộn vào làm thành viên"
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "ten_vi_thuoc": "Xà sàng tử",
#       "lieu_luong": "40g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ"
#     },
#     {
#       "ten_bai_thuoc": "Lòi dom",
#       "ten_vi_thuoc": "Cam thảo",
#       "lieu_luong": "40g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Tán nhỏ"
#     }
#   ]
# }
# ================================================================================
# 2025-11-21 19:09:11 - HerbExtractor - INFO - Extracted: 1 herbs, 3 prescriptions, 7 formulas
# 2025-11-21 19:09:16 - HerbExtractor - INFO -
# Processing text chunk 18/67
# 2025-11-21 19:09:16 - HerbExtractor - INFO - Pages 52-57: 1069 chars
# 2025-11-21 19:09:16 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "RAU SAM",
#       "ten_goi_khac": "mã xỉ hiện; pourpier",
#       "ten_khoa_hoc": "Portulaca oleracea L.",
#       "ho_thuc_vat": "Portulacaceae",
#       "mo_ta": "Rau sam là một loại cỏ sống hàng năm, có nhiều cành mẫm, nhẵn. Thân có màu đỏ nhạt, dài 10 đến 30cm. Lá hình bầu dục dài, phía đáy lá hơi thót lại, không cuống, phiến lá dày, mặt bóng, dài 2cm, rộng 8-14mm. Những lá phía trên họp thành một thứ tổng bao quanh các hoa. Hoa mọc ở đầu cành, màu vàng, không có cuống. Quả nang bình cầu, mở bằng 1 nắp. Trong có chứa nhiều hạt màu đen bóng (hình 127,Hm 24,1)",
#       "phan_bo_thu_hai_che_bien": "Rau sam mọc hoang ở khắp những nơi ẩm ướt của nước ta. Còn thấy mọc ở nhiều nước khác như Trung Quốc, Nhật Bản, Ấn Độ, Châu Âu. Tại nhiều nước châu Âu, nhất là ở Pháp, người ta trồng làm rau ăn, vị chua dễ chịu gọi là pourpier.",
#       "thanh_phan_hoa_hoc": "Hoạt chất của rau sam hiện nay chưa rõ. Chỉ mới biết trong rau sam có 6,49% hydrat cacbon, 0,5% chất béo, 1,8% chất protit, 2,23% tro. Một tài liệu khác (Trung Quốc khoa học xã hội Trung dược tân biên trích dẫn) thì có vitamin C, men",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "Không có thông tin",
#       "lieu_dung": "Không có thông tin",
#       "ghi_chu": "Không có thông tin"
#     }
#   ],
#   "bai_thuoc": [],
#   "cong_thuc": []
# }
# ================================================================================
# 2025-11-21 19:09:18 - HerbExtractor - INFO - Extracted: 1 herbs, 0 prescriptions, 0 formulas
# 2025-11-21 19:09:22 - HerbExtractor - INFO -
# Processing text chunk 19/67
# 2025-11-21 19:09:22 - HerbExtractor - INFO - Pages 55-60: 5683 chars
# 2025-11-21 19:09:22 - HerbExtractor - INFO - API call 1/5
# ================================================================================
# DEBUG
# ================================================================================
# ================================================================================
# RESPONSE TEXT
# {
#   "vi_thuoc": [
#     {
#       "ten_viet_nam": "NGƯU TẤT",
#       "ten_goi_khac": "cây cỏ xước; hoài ngưu tất",
#       "ten_khoa_hoc": "Achyranthes bidentata Blume",
#       "ho_thuc_vat": "Giền Amaranthaceae",
#       "mo_ta": "Cây ngưu tất là một loại cỏ xước cho nên người ta nhầm với cây cỏ xước Achyranthes aspera L. Cỏ có thân mảnh, hơi vuông, thường chỉ cao 1m, cũng có khi tới 2m. Lá mọc đối có cuống, dài 5-12cm, rộng 2-4cm, phiến lá hình trứng, đầu nhọn, mép có răng cưa. Cụm hoa mọc thành bông ở kẽ lá và đầu cành.",
#       "phan_bo_thu_hai_che_bien": "Cây ngưu tất mọc hoang ở nhiều nơi trong nước ta. Tại các tỉnh, nhất là thành phố, một số gia đình trồng làm cảnh. Ta dùng rễ phơi hay sấy khô- Radix Achyranthis bidentatae- của cây ngưu tất.",
#       "thanh_phan_hoa_hoc": "Trong đương quy có tinh dầu. Có tác giả đã xác định tỷ lệ tinh dầu là 0,2%, tinh dầu có tỷ trọng 0,955 ở 15°C, màu vàng sẫm, trong; tỷ lệ axit tự do trong tinh dầu chiếm tới 40%; thành phần chủ yếu của tinh dầu giống tinh dầu của đương quy Nhật Bản (Dược học thông báo, 1954, trang 432 và Thực vật dược phẩm hóa học của Lâm Khải Thọ, tr. 384).",
#       "tac_dung_duoc_ly": "Thược dược được dùng làm thuốc giảm đau, thông kinh trong những bệnh đau bụng (do ruột co bóp quá mạnh), nhức đầu, chân tay nhức mỏi, còn dùng chữa phụ nữ bế kinh, xích bạch đới lâu năm không khỏi.",
#       "tinh_vi": "Vị chua, đắng, bình, không độc",
#       "quy_kinh": "vào hai kinh can, tỳ và phế",
#       "cong_dung": "nhuận gan, làm hết đau, dưỡng huyết, liễm âm, lợi tiểu, dùng chữa đau bụng, tả lỵ, lưng ngực đau, kinh nguyệt không đều, mồ hôi trộm, tiểu tiện khó.",
#       "lieu_dung": "6-12g/ngày",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "BÔNG",
#       "ten_goi_khac": "cây bông; bông báo; cây bông vải",
#       "ten_khoa_hoc": "Gossypium sp",
#       "ho_thuc_vat": "Bông Malvaceae",
#       "mo_ta": "Không có thông tin",
#       "phan_bo_thu_hai_che_bien": "Ta dùng vỏ rễ cây bông (Cortex Gossypii radicis) là dư phẩm của kỹ nghệ trồng bông. Sau khi hái cây bông ta đào rễ rửa sạch, bóc lấy vỏ phơi khô.",
#       "thanh_phan_hoa_hoc": "Trong vỏ rễ cây bông có chứa sinh tố K, chất gossypola C15H30O4, một ít tinh dầu, một ít tanin.",
#       "tac_dung_duoc_ly": "Liên Xô cũ công nhận vỏ rễ cây bông là một vị thuốc chính thức dùng dưới dạng cao lỏng làm thuốc cầm máu tử cung. Nhân dân ta và một số nước khác dùng làm thuốc điều kinh. Nó gây co bóp tử cung giống như sự co bóp tự nhiên khi đẻ.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "cầm máu tử cung, điều kinh.",
#       "lieu_dung": "3-5g/ngày",
#       "ghi_chu": "Nên chú ý nghiên cứu thêm."
#     },
#     {
#       "ten_viet_nam": "HOA HÒE",
#       "ten_goi_khac": "hòe; hòe mễ",
#       "ten_khoa_hoc": "Sophora japonica L",
#       "ho_thuc_vat": "Cánh bướm Fabaceae",
#       "mo_ta": "Cây hòe là một cây to, cao 10-20m, cành non màu xanh lục, cành già màu xám. Lá kép lông chim lẻ, gồm 7-17 lá chét, hình trứng, dài 2-5cm, rộng 1-2cm. Hoa màu trắng ngà, mọc thành chùm ở đầu cành. Quả là một loại đậu dài 5-8cm, thắt eo lại ở giữa các hạt, màu xanh lục, khi chín màu đen.",
#       "phan_bo_thu_hai_che_bien": "Cây hòe được trồng ở nhiều nơi trong nước ta, nhất là ở các tỉnh đồng bằng và trung du. Người ta dùng nụ hoa (hòe mễ) và quả (hòe tử) làm thuốc. Nụ hoa thu hái vào lúc nụ còn chưa nở, phơi hay sấy khô. Quả thu hái vào mùa thu, phơi khô.",
#       "thanh_phan_hoa_hoc": "Trong nụ hoa hòe có 10-30% rutin, một glucozit có tác dụng làm bền thành mạch máu. Trong quả hòe có rutin, chất béo, tanin.",
#       "tac_dung_duoc_ly": "Rutin có tác dụng làm bền thành mạch máu, chữa các bệnh do thành mạch máu dễ vỡ.",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "chữa bệnh trĩ, ho ra máu, chảy máu cam, cao huyết áp.",
#       "lieu_dung": "Nụ hoa hòe 10-20g, quả hòe 10-15g/ngày",
#       "ghi_chu": "Không có thông tin"
#     },
#     {
#       "ten_viet_nam": "HOA CỨT LỢN",
#       "ten_goi_khac": "cây hoa ngũ sắc; cây hoa ngũ vị; cỏ hôi",
#       "ten_khoa_hoc": "Ageratum conyzoides L",
#       "ho_thuc_vat": "Cúc Asteraceae",
#       "mo_ta": "Cây hoa cứt lợn là một cây nhỏ, mọc hàng năm, thân có nhiều lông nhỏ mềm, cao chừng 25-50cm, mọc hoang ở khắp nơi trong nước ta. Lá mọc đối, hình trứng hay 3 cạnh, dài 2-6cm, rộng 1-3cm, mép có răng cưa tròn, hai mặt đều có lông, mặt dưới của lá nhạt hơn. Hoa nhỏ, màu tím, xanh. Quả bế màu đen, có 5 sống dọc.",
#       "phan_bo_thu_hai_che_bien": "Cây hoa cứt lợn mọc hoang ở khắp nơi trong nước ta.",
#       "thanh_phan_hoa_hoc": "Chưa thấy tài liệu nghiên cứu.",
#       "tac_dung_duoc_ly": "Không có thông tin",
#       "tinh_vi": "Không có thông tin",
#       "quy_kinh": "Không có thông tin",
#       "cong_dung": "chữa bệnh phụ nữ bị rong huyết sau khi sinh nở, chữa viêm xoang mũi dị ứng, dùng nấu nước gội đầu sạch gầu trơn tóc.",
#       "lieu_dung": "30-50g/ngày (cây tươi)",
#       "ghi_chu": "Đừng nhầm cây cứt lợn nói đây với cây bông ổi (ngũ sắc) và cây hy thiêm nhiều nơi cũng gọi là cây cứt lợn."
#     }
#   ],
#   "bai_thuoc": [
#     {
#       "ten_bai_thuoc": "Thược dược cam thảo thang",
#       "chu_tri": "2 chân và đầu gối đau nhức không co duỗi được, đau bụng",
#       "nguon_goc": "Trương Trọng Cảnh",
#       "ghi_chu": "Thược dược 8g, cam thảo 4g, nước 300ml, sắc còn 100ml, chia 2 lần uống trong ngày"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "chu_tri": "đầu nhức mắt hoa",
#       "nguon_goc": "Trương Trọng Cảnh",
#       "ghi_chu": "Quế chi 6g, thược dược 6g, đại táo 6g, sinh khương 6g, phục linh 6g, bạch truật 6g, cam thảo 4g, nước 600ml, sắc còn 200ml, chia 3 lần uống trong ngày"
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc có vỏ rễ cây bông",
#       "chu_tri": "điều kinh, thông kinh",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Vỏ rễ cây bông 3g, nước 300ml, sắc còn 100ml. Uống trong ngày"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "chu_tri": "bệnh trĩ",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Hoa hòe 10g, kinh giới 10g, đương quy 10g, chỉ xác 10g, phòng phong 6g, sắc uống"
#     },
#     {
#       "ten_bai_thuoc": "Chữa chảy máu cam",
#       "chu_tri": "chảy máu cam",
#       "nguon_goc": "Không có thông tin",
#       "ghi_chu": "Hoa hòe 10g, sinh địa 10g, trắc bá diệp 10g, kinh giới 10g, sắc uống"
#     }
#   ],
#   "cong_thuc": [
#     {
#       "ten_bai_thuoc": "Thược dược cam thảo thang",
#       "ten_vi_thuoc": "Thược dược",
#       "lieu_luong": "8g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Thược dược cam thảo thang",
#       "ten_vi_thuoc": "Cam thảo",
#       "lieu_luong": "4g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Quế chi",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Thược dược",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Đại táo",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Sinh khương",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Phục linh",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Bạch truật",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Quế chi gia linh truật",
#       "ten_vi_thuoc": "Cam thảo",
#       "lieu_luong": "4g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Đơn thuốc có vỏ rễ cây bông",
#       "ten_vi_thuoc": "Vỏ rễ cây bông",
#       "lieu_luong": "3g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "ten_vi_thuoc": "Hoa hòe",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "ten_vi_thuoc": "Kinh giới",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "ten_vi_thuoc": "Đương quy",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "ten_vi_thuoc": "Chỉ xác",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa bệnh trĩ",
#       "ten_vi_thuoc": "Phòng phong",
#       "lieu_luong": "6g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa chảy máu cam",
#       "ten_vi_thuoc": "Hoa hòe",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa chảy máu cam",
#       "ten_vi_thuoc": "Sinh địa",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa chảy máu cam",
#       "ten_vi_thuoc": "Trắc bá diệp",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     },
#     {
#       "ten_bai_thuoc": "Chữa chảy máu cam",
#       "ten_vi_thuoc": "Kinh giới",
#       "lieu_luong": "10g",
#       "vai_tro": "Không có thông tin",
#       "ghi_chu_che_bien": "Không có thông tin"
#     }
#   ]
# }
# ================================================================================
# 2025-11-21 19:09:31 - HerbExtractor - INFO - Extracted: 4 herbs, 5 prescriptions, 19 formulas

# %% [markdown]
# ## **3. Load processed data**

# %%
print("Loading processed datasets...\n")

# Load all three datasets
df_vi_thuoc = pd.read_csv(settings.OUTPUT_CSV_VI_THUOC)
df_bai_thuoc = pd.read_csv(settings.OUTPUT_CSV_BAI_THUOC)
df_cong_thuc = pd.read_csv(settings.OUTPUT_CSV_CONG_THUC)

# Also load JSON for reference
with open(settings.OUTPUT_JSON, 'r', encoding='utf-8') as f:
    data_json = json.load(f)

print(f"Loaded {len(df_vi_thuoc):,} medicinal herbs")
print(f"Loaded {len(df_bai_thuoc):,} prescriptions")
print(f"Loaded {len(df_cong_thuc):,} formulas")

# %% [markdown]
# ## **4. Dataset dimensions and info**

# %%
datasets = {
    'Vị thuốc (Herbs)': df_vi_thuoc,
    'Bài thuốc (Prescriptions)': df_bai_thuoc,
    'Công thức (Formulas)': df_cong_thuc
}

for name, df in datasets.items():
    print(f"\n{name}:")
    print(f"Rows: {len(df):,}")
    print(f"Columns: {len(df.columns)}")
    print(f"Memory: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    print(f"Columns: {', '.join(df.columns.tolist())}")

# %%
def analyze_missing_data(df, name):
    print(f"\n{name}")
    print("-" * 60)
    
    missing = df.isnull().sum()
    missing_pct = (missing / len(df)) * 100
    
    missing_df = pd.DataFrame({
        'Column': missing.index,
        'Missing Count': missing.values,
        'Missing %': missing_pct.values
    }).sort_values('Missing %', ascending=False)
    
    # Filter only columns with missing data
    missing_df = missing_df[missing_df['Missing Count'] > 0]
    
    if len(missing_df) > 0:
        print(missing_df.to_string(index=False))
    else:
        print("✓ No missing values detected!")
    
    return missing_df

missing_herbs = analyze_missing_data(df_vi_thuoc, "Vị thuốc")
missing_prescriptions = analyze_missing_data(df_bai_thuoc, "Bài thuốc")
missing_formulas = analyze_missing_data(df_cong_thuc, "Công thức")
